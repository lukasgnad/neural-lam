# %%
import xarray as xr
import cftime

ds = xr.open_dataset('/hkfs/work/workspace/scratch/xo8179-ukesm/global_1985_2014_equiangular_wp_conservative_40_chunks_forecasts/z64_graphcast.zarr', decode_timedelta=True)

# %%
print(ds)
# Out:
# <xarray.Dataset> Size: 7GB
# Dimensions:                      (time: 110, prediction_timedelta: 40,
#                                   longitude: 128, latitude: 64, level: 6)
# Coordinates:
#   * latitude                     (latitude) float64 512B -90.0 -87.14 ... 90.0
#   * level                        (level) float32 24B 925.0 850.0 ... 300.0 200.0
#   * longitude                    (longitude) float64 1kB 0.0 2.812 ... 357.2
#   * prediction_timedelta         (prediction_timedelta) timedelta64[ns] 320B ...
#   * time                         (time) object 880B 2011-01-01 06:00:00 ... 2...
# Data variables: (12/14)
#     10m_wind_speed               (time, prediction_timedelta, longitude, latitude) float32 144MB ...
#     geopotential_500             (time, prediction_timedelta, longitude, latitude) float32 144MB ...
#     mean_sea_level_pressure      (time, prediction_timedelta, longitude, latitude) float32 144MB ...
# ...

# %%
print(ds.prediction_timedelta)
# Out:
# <xarray.DataArray 'prediction_timedelta' (prediction_timedelta: 40)> Size: 320B
# array([  6,  12,  18,  24,  30,  36,  42,  48,  54,  60,  66,  72,  78,  84,
#         90,  96, 102, 108, 114, 120, 126, 132, 138, 144, 150, 156, 162, 168,
#        174, 180, 186, 192, 198, 204, 210, 216, 222, 228, 234, 240],
#       dtype='timedelta64[h]')
# Coordinates:
#   * prediction_timedelta  (prediction_timedelta) timedelta64[h] 320B 06:00:00...
# Attributes:
#     units:    hours
