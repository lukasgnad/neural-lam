# %%
import xarray as xr
from matplotlib import pyplot as plt
import xarray as xr
from scipy.stats import wasserstein_distance
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import sys
sys.path.insert(
    1, "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/evaluation"
)
import plot_utils as plot
import distribution_analysis as dist
import numpy as np
dist_folder = '/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_nextgems_new/distributions'

# %%
model_short_names = ['z64-MM','z128-MM','z256-MM','z64-H']
model_idx=0

model_short_name = model_short_names[model_idx]
selected_model_past=plot.PAST_MODELS_UKESM[model_idx]
selected_model_future=plot.FUTURE_MODELS_UKESM[model_idx]
print(f'Evaluating model: {selected_model_past["model_name"]}')

base_save_folder_past = selected_model_past['plot_folder']
base_save_folder_future = selected_model_future['plot_folder']

ukesm_past_forecasts = plot.fix_lon_lat(xr.open_zarr(selected_model_past['forecasts'], decode_timedelta=True).astype(np.float32))
ukesm_future_forecasts = plot.fix_lon_lat(xr.open_zarr(selected_model_future['forecasts'], decode_timedelta=True).astype(np.float32))

ukesm_past_truth = plot.fix_lon_lat(xr.open_zarr(selected_model_past['ground_truth']).astype(np.float32))
ukesm_future_truth = plot.fix_lon_lat(xr.open_zarr(selected_model_future['ground_truth']).astype(np.float32))

ukesm_train = plot.fix_lon_lat(xr.open_zarr('/hkfs/work/workspace/scratch/xo8179-ukesm/global_1985_2014_equiangular_wp_conservative_40_chunks/fields.zarr').astype(np.float32))
ukesm_train = ukesm_train.sel(time=slice("1985", "2010"))
# Out:
# Evaluating model: UKESM z64 Multi-Mesh

# %%
def create_folder_if_not_exists(folder):
    from pathlib import Path
    Path(folder).mkdir(parents=True, exist_ok=True)

# %%
create_folder_if_not_exists(base_save_folder_past)
create_folder_if_not_exists(base_save_folder_future)

# %% [markdown]
# # Calculate the dist shift between train, T1 and T2 truth

# %%
save_path = '/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/hist_future_dist_shift_new/'
create_folder_if_not_exists(save_path)
# steps=[6, 48]#, 5*24, 10*24]
num_vars = len(plot.KEY_VARIABLES_UKESM)

# for var_index in range(num_vars):
for var_index in range(num_vars):
    display_name, unit, variable, plevel,_ = plot.KEY_VARIABLES_UKESM[var_index]
    error=False
    print(f'Processing var {display_name} ({var_index+1}/{num_vars})')
    try:
        train_dist = dist.load_dist(variable, dataset='U',dataslice_name='TR', is_ground_truth=True)
        past_test_dist = dist.load_dist(variable, dataset='U',dataslice_name='T1', is_ground_truth=True)
        future_test_dist = dist.load_dist(variable, dataset='U',dataslice_name='T2', is_ground_truth=True)
    except(Exception):
        error=True
        if plevel:
            past = ukesm_past_truth.sel(level=plevel)[variable]
            future=ukesm_future_truth.sel(level=plevel)[variable]
        else:
            past = ukesm_past_truth[variable]
            future=ukesm_future_truth[variable]
    
        past_train=past.sel(time=slice('1985','2010'))
        past_test=past.sel(time=slice('2011','2014'))
    
        if variable == 'total_precipitation_6hr':
            past_train=past_train*plot.UKESM_PRECIP_CONST
            past_test = past_test*plot.UKESM_PRECIP_CONST
            future=future*plot.UKESM_PRECIP_CONST
        elif variable == 'geopotential_500':
            past_train=past_train*plot.UKESM_GEOPOT_CONST
            past_test = past_test*plot.UKESM_GEOPOT_CONST
            future=future*plot.UKESM_GEOPOT_CONST
    
        if plevel and plevel>500:
            print(f"    Applying mask... ")
            past_train = plot.get_masked_ukesm_data(past_train, plevel=plevel)
            past_test = plot.get_masked_ukesm_data(past_test, plevel=plevel)
            future = plot.get_masked_ukesm_data(future, plevel=plevel)
    
        train_dist = dist.calc_single_dist_with_nans(past_train)
        past_test_dist = dist.calc_single_dist_with_nans(past_test)
        future_test_dist = dist.calc_single_dist_with_nans(future)

        
    train_dist['label'] = 'U_TR'
    past_test_dist['label'] = 'U_T1'
    future_test_dist['label'] = 'U_T2'
    train_dist['label_full'] = 'Train 1985-2010 (U_TR)'
    past_test_dist['label_full'] = 'Test 2011-2014 (U_T1)'
    future_test_dist['label_full'] = 'Test 2097-2100 (U_T2)'
    colors=['grey', 'C0', 'C1']
    plot_5_quant = variable in ['u_component_of_wind','v_component_of_wind','relative_vorticity']

    if error:
        dist.precompute_and_save_distribution(train_dist, variable, dataset='U',dataslice_name='TR', is_ground_truth=True)
        dist.precompute_and_save_distribution(past_test_dist, variable, dataset='U',dataslice_name='T1', is_ground_truth=True)
        dist.precompute_and_save_distribution(future_test_dist, variable, dataset='U',dataslice_name='T2', is_ground_truth=True)
    
    dist.plot_distributions_with_nans([train_dist,past_test_dist,future_test_dist],
                                    bins=500,
                                    variable_name=display_name,
                                    unit=unit,
                                    colors=colors,
                                    title=f"UKESM Distribution shift: {display_name}",
                                    save_to=save_path+f'{variable}{f"_at_{plevel}" if plevel else ""}.png',
                                 plot_5_quantile=plot_5_quant, plot_size=(6,5)
                                )
    dist.plot_distributions_with_nans([train_dist,past_test_dist,future_test_dist],
                                    bins=500,
                                    variable_name=display_name,
                                    unit=unit,
                                    colors=colors,
                                    title=f"UKESM Distribution shift: {display_name}",
                                    save_to=save_path+f'{variable}{f"_at_{plevel}" if plevel else ""}_wide.png',
                                 plot_5_quantile=plot_5_quant, plot_size=(9,5)
                                )
    dist.plot_distributions_with_nans([train_dist,past_test_dist,future_test_dist],
                                    bins=500,
                                    variable_name=display_name,
                                    unit=unit,
                                    colors=colors,
                                    title=f"UKESM Distribution shift: {display_name}",
                                    save_to=save_path+f'{variable}{f"_at_{plevel}" if plevel else ""}.pdf',
                                 plot_5_quantile=plot_5_quant, plot_size=(6,5)
                                )
    dist.plot_distributions_with_nans([train_dist,past_test_dist,future_test_dist],
                                    bins=500,
                                    variable_name=display_name,
                                    unit=unit,
                                    colors=colors,
                                    title=f"UKESM Distribution shift: {display_name}",
                                    save_to=save_path+f'{variable}{f"_at_{plevel}" if plevel else ""}_wide.pdf',
                                 plot_5_quantile=plot_5_quant, plot_size=(9,5)
                                )

# %%
train_dist['label'] = 'TR'
past_test_dist['label'] = 'T1'
future_test_dist['label'] = 'T2'
train_dist['label_full'] = 'Train 1985-2010 (TR)'
past_test_dist['label_full'] = 'Test 2011-2014 (T1)'
future_test_dist['label_full'] = 'Test 2097-2100 (T2)'
colors=['grey', 'C0', 'C1']
plot_distributions_with_nans([train_dist,past_test_dist,future_test_dist],
                                 bins=200,
                                 variable_name=display_name,
                                 unit=unit,
                                 colors=colors,
                                 title=f"Distribution shift: {display_name}",
                                save_to=save_path+f'{variable}{f"_at_{plevel}" if plevel else ""}.png')

# %% [markdown]
# # Compute and plot - Non-Interpolated

# %%
compute = False

model_short_names = ['z64-MM','z128-MM','z256-MM','z64-H']
model_idx=0
past_eval = [False, True]


for model_idx in range(len(model_short_names)):
    model_short_name = model_short_names[model_idx]
    selected_model_past=plot.PAST_MODELS_UKESM[model_idx]
    selected_model_future=plot.FUTURE_MODELS_UKESM[model_idx]
    print(f'Evaluating model: {selected_model_past["model_name"]}')
    
    base_save_folder_past = selected_model_past['plot_folder']
    base_save_folder_future = selected_model_future['plot_folder']

    for past in past_eval:
    
        selected_model = selected_model_past if past else selected_model_future
        print(selected_model['id'])
            
        save_to=base_save_folder_past+'distribution_shift_forecast/' if past else base_save_folder_future+'distribution_shift_forecast/'
        save_to='/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/'
        save_name=f'UKESM_{model_short_name}_{"hist" if past else "future"}_dist_shift_all_vars_24_120_240.pdf'
        print(save_to+save_name)
        steps=[24, 5*24, 10*24]
        # steps=[6, 48]#, 5*24, 10*24]
        num_vars = len(plot.KEY_VARIABLES_UKESM)
        precip_p99=0
        
        fig, axes = plt.subplots(nrows=num_vars, ncols=len(steps), figsize=(4*len(steps),2*num_vars), sharex=False, sharey='row')
        create_folder_if_not_exists(save_to)
        for var_index in range(num_vars):
        # for var_index in range(6,7):
            
            display_name, unit, variable, plevel,_ = plot.KEY_VARIABLES_UKESM[var_index]
            plot_5_quant = variable in ['u_component_of_wind','v_component_of_wind','relative_vorticity']
            print(f'Processing var {display_name} ({var_index+1}/{num_vars})')
            train_dist_UKESM = dist.load_dist(variable, dataset='U',dataslice_name='TR', is_ground_truth=True)
            train_dist_UKESM['label'] = 'U_TR'
            train_dist_UKESM['label_full'] = 'U_TR'
                  
            for i, hours_into_future in enumerate(steps):
                print(f'    Calculating distribution {i+1} of {len(steps)}')
                ax = axes[var_index, i]
                
                if compute:
                    ukesm_past_forecasts = plot.open_zarr_ukesm(selected_model_past['forecasts'])
                    ukesm_future_forecasts = plot.open_zarr_ukesm(selected_model_future['forecasts'])
                    
                    ukesm_past_truth = plot.open_zarr_ukesm(selected_model_past['ground_truth'])
                    ukesm_future_truth = plot.open_zarr_ukesm(selected_model_future['ground_truth'])
                    
                    ds_test_truth, ds_test_forecast = dist.get_datasets_after(ukesm_past_truth, ukesm_past_forecasts, hours_into_future) if past else dist.get_datasets_after(ukesm_future_truth, ukesm_future_forecasts, hours_into_future) 
                    truth=ds_test_truth.sel(level=plevel)[variable] if plevel else ds_test_truth[variable]
                    forecast=ds_test_forecast.sel(level=plevel)[variable] if plevel else ds_test_forecast[variable]

                    mult = plot.get_multiplier_ukesm(variable)
                    if not mult == 1:
                        print(f"Multiplying data by {mult}")
                
                    # Select variable
                    truth = truth * mult
                    forecast = forecast * mult
    
                        
            
                    if plevel and plevel>500:
                        print(f"    Applying mask... ")
                        forecast = plot.get_masked_ukesm_data(forecast, plevel=plevel)
                        truth = plot.get_masked_ukesm_data(truth, plevel=plevel)
                    
                    forecast_dist=dist.calc_single_dist_with_nans(forecast)
                    truth_dist=dist.calc_single_dist_with_nans(truth)

                    
                    forecast_dist['label'] = 'F'
                    forecast_dist['label_full'] = 'Forecast (F)'
                    
    
                    dist.precompute_and_save_distribution(forecast_dist, variable, dataset='U',dataslice_name='T1' if past else 'T2', is_ground_truth=False, rollout=hours_into_future, model_id=selected_model['id'])
                    dist.precompute_and_save_distribution(truth_dist, variable, dataset='U',dataslice_name='T1' if past else 'T2', is_ground_truth=True, rollout=hours_into_future)
                
                else:
                    truth_dist = dist.load_dist(variable, dataset='U',dataslice_name='T1' if past else 'T2', is_ground_truth=True, rollout=hours_into_future)
                    forecast_dist = dist.load_dist(variable, dataset='U',dataslice_name='T1' if past else 'T2', is_ground_truth=False, rollout=hours_into_future, model_id=selected_model['id'])
                    
    
                if past:
                    truth_dist['label'] = 'U_T1'
                    truth_dist['label_full'] = 'U_T1'
                    forecast_dist['label'] = ''
                    forecast_dist['label_full'] = f'Forecast'
                else:
                    truth_dist['label'] = 'U_T2'
                    truth_dist['label_full'] = 'U_T2'
                    forecast_dist['label'] = ''
                    forecast_dist['label_full'] = f'Forecast'
                if (variable == 'total_precipitation_6hr') and i ==0:
                        precip_p99=truth_dist['p99']
                dist.plot_distributions_with_nans_on_axis(ax,
                                                     [truth_dist, forecast_dist],
                                                     background=[train_dist_UKESM],
                                                     bin_num=1000 if (variable == 'total_precipitation_6hr') else 500,
                                                     variable_name=display_name,
                                                     unit=unit,
                                                     title=f"{display_name} After {hours_into_future}h" if i==0 else f"After {hours_into_future}h",
                                                     plot_legend=False,
                                                     plot_5_quantile=plot_5_quant,plot_99_quant=(variable == 'total_precipitation_6hr'))
        
        min_x = [4.5, 225, -9999, 200, -9999,-9999,-9999,-9999]
        #formatter = ScalarFormatter(useMathText=True)
        #formatter.set_powerlimits((-2, 2))   # show x×10^n when |value| < 10^-3 or > 10^3
                
        for var_index in range(num_vars):
            display_name, unit, variable, plevel, _ = plot.KEY_VARIABLES_UKESM[var_index]
            # collect all limits in this row
            xmins, xmaxs = [], []
            ymins, ymaxs = [], []
            for i, hours_into_future in enumerate(steps):
                ax = axes[var_index, i]
                xmin, xmax = ax.get_xlim()
                ymin, ymax = ax.get_ylim()
                xmins.append(xmin)
                xmaxs.append(xmax)
                ymins.append(ymin)
                ymaxs.append(ymax)
            # set same limits for all in row i
            row_xlim = (max(min(xmins),min_x[var_index]), max(xmaxs))
            if not variable == 'total_precipitation_6hr':
                row_xlim = dist.get_xlim(display_name, dataset='ukesm')
            row_ylim = (min(ymins), max(ymaxs))
            for i, hours_into_future in enumerate(steps):
                axes[var_index, i].set_xlim(row_xlim)
                if variable == 'total_precipitation_6hr':
                    axes[var_index, i].set_yscale('log')
                else:
                    axes[var_index, i].set_ylim(row_ylim)
                if i > 0:
                    axes[var_index, i].set_ylabel("")              # remove the label
                    axes[var_index, i].tick_params(labelleft=False)  # remove tick labels
                # axes[var_index, i].tick_params(bottom=True, top=False)
                # axes[var_index, i].xaxis.get_major_ticks()[0].set_visible(False)      # hide the leftmost tick
                # axes[var_index, i].xaxis.get_major_ticks()[-1].set_visible(False)     # hide the rightmost tick
                from matplotlib.ticker import ScalarFormatter
                offset = axes[var_index, i].xaxis.get_offset_text()
                offset.set_fontsize(9)
                
                # axes[var_index, i].xaxis.set_major_formatter(formatter)
                axes[var_index, i].ticklabel_format(axis="x", style="sci", scilimits=(-2, 3))
                if i ==0 and not 'precipitation' in display_name.lower():
                    axes[var_index, i].ticklabel_format(axis="y", style="sci", scilimits=(-2, 3))
                    offset = axes[var_index, i].yaxis.get_offset_text()
                    offset.set_x(-0.12)
                    offset.set_fontsize(9)
        fig.suptitle(f"UKESM {'U_T1' if past else 'U_T2'}:\n{model_short_name}", fontsize=16, y=0.96)
        from matplotlib.patches import Patch
        
        legend_elements = [
            Patch(facecolor="gray", edgecolor="none", label="Train UKESM 1985–2010 (U_TR)"),
            Patch(facecolor="C0", edgecolor="none", label="Test UKESM 2011–2014 (U_T1)" if past else "Test UKESM 2097–2100 (U_T2)")
        ]
        from matplotlib.lines import Line2D
        abbrev='U_T1' if past else 'U_T2'
        legend_elements += [
            Line2D([0], [0], color="C0",linestyle=(0, (1, 0)), lw=2, label=f"{abbrev} mean"),
            Line2D([0], [0], color="C0", lw=2, linestyle=(0, (1, 3)), label=f"{abbrev} 95th % (99.9th % for Precipitation)"),
            Line2D([0], [0], color="C0", lw=2, linestyle=(0, (5, 3)), label=f"{abbrev} 5th %")
        ]
            
        
        fig.legend(
            handles=legend_elements,
            loc="upper left",
            bbox_to_anchor=(0.04, 0.99),
        )

        
        legend_elements = [
            Patch(facecolor="C1", edgecolor="none", label="Forecast 2011–2014" if past else "Forecast 2097–2100")
        ]

        legend_elements += [
            Line2D([0], [0], color="C1",linestyle=(0, (1, 0)), lw=2, label="Forecast mean"),
            Line2D([0], [0], color="C1", lw=2, linestyle=(0, (1, 3)), label="Forecast 95th % (99.9th % for Precipitation)"),
            Line2D([0], [0], color="C1", lw=2, linestyle=(0, (5, 3)), label="Forecast 5th %")
        ]
            
        
        fig.legend(
            handles=legend_elements,
            loc="upper right",
            bbox_to_anchor=(0.98, 0.99),
        )
        
        fig.tight_layout(rect=[0, 0, 1, 0.96])
        plt.savefig(save_to+save_name, bbox_inches="tight", dpi=600)
        plt.close()
# Out:
# Evaluating model: UKESM z64 Multi-Mesh
# z64_future
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_z64-MM_future_dist_shift_all_vars_24_120_240.pdf
# Processing var Geopotential at 500hPa (1/8)
# loading U_TR/GT_geopotential_500.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_geopotential_500_24.npz
# loading U_T2/FC_geopotential_500_24_z64_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_geopotential_500_120.npz
# loading U_T2/FC_geopotential_500_120_z64_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_geopotential_500_240.npz
# loading U_T2/FC_geopotential_500_240_z64_future.npz
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_temperature_24.npz
# loading U_T2/FC_temperature_24_z64_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_temperature_120.npz
# loading U_T2/FC_temperature_120_z64_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_temperature_240.npz
# loading U_T2/FC_temperature_240_z64_future.npz
# Processing var Specific Humidity at 700hPa (3/8)
# loading U_TR/GT_specific_humidity.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_specific_humidity_24.npz
# loading U_T2/FC_specific_humidity_24_z64_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_specific_humidity_120.npz
# loading U_T2/FC_specific_humidity_120_z64_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_specific_humidity_240.npz
# loading U_T2/FC_specific_humidity_240_z64_future.npz
# Processing var 1.5m Temperature (4/8)
# loading U_TR/GT_surface_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_surface_temperature_24.npz
# loading U_T2/FC_surface_temperature_24_z64_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_surface_temperature_120.npz
# loading U_T2/FC_surface_temperature_120_z64_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_surface_temperature_240.npz
# loading U_T2/FC_surface_temperature_240_z64_future.npz
# Processing var U-Component of Wind at 850hPa (5/8)
# loading U_TR/GT_u_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_u_component_of_wind_24.npz
# loading U_T2/FC_u_component_of_wind_24_z64_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_u_component_of_wind_120.npz
# loading U_T2/FC_u_component_of_wind_120_z64_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_u_component_of_wind_240.npz
# loading U_T2/FC_u_component_of_wind_240_z64_future.npz
# Processing var V-Component of Wind at 850hPa (6/8)
# loading U_TR/GT_v_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_v_component_of_wind_24.npz
# loading U_T2/FC_v_component_of_wind_24_z64_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_v_component_of_wind_120.npz
# loading U_T2/FC_v_component_of_wind_120_z64_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_v_component_of_wind_240.npz
# loading U_T2/FC_v_component_of_wind_240_z64_future.npz
# Processing var Total Precipitation (7/8)
# loading U_TR/GT_total_precipitation_6hr.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_total_precipitation_6hr_24.npz
# loading U_T2/FC_total_precipitation_6hr_24_z64_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_total_precipitation_6hr_120.npz
# loading U_T2/FC_total_precipitation_6hr_120_z64_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_total_precipitation_6hr_240.npz
# loading U_T2/FC_total_precipitation_6hr_240_z64_future.npz
# Processing var Rel. Vorticity at 500hPa (8/8)
# loading U_TR/GT_relative_vorticity.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_relative_vorticity_24.npz
# loading U_T2/FC_relative_vorticity_24_z64_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_relative_vorticity_120.npz
# loading U_T2/FC_relative_vorticity_120_z64_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_relative_vorticity_240.npz
# loading U_T2/FC_relative_vorticity_240_z64_future.npz
# z64_past
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_z64-MM_hist_dist_shift_all_vars_24_120_240.pdf
# Processing var Geopotential at 500hPa (1/8)
# loading U_TR/GT_geopotential_500.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_geopotential_500_24.npz
# loading U_T1/FC_geopotential_500_24_z64_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_geopotential_500_120.npz
# loading U_T1/FC_geopotential_500_120_z64_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_geopotential_500_240.npz
# loading U_T1/FC_geopotential_500_240_z64_past.npz
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_temperature_24.npz
# loading U_T1/FC_temperature_24_z64_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_temperature_120.npz
# loading U_T1/FC_temperature_120_z64_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_temperature_240.npz
# loading U_T1/FC_temperature_240_z64_past.npz
# Processing var Specific Humidity at 700hPa (3/8)
# loading U_TR/GT_specific_humidity.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_specific_humidity_24.npz
# loading U_T1/FC_specific_humidity_24_z64_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_specific_humidity_120.npz
# loading U_T1/FC_specific_humidity_120_z64_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_specific_humidity_240.npz
# loading U_T1/FC_specific_humidity_240_z64_past.npz
# Processing var 1.5m Temperature (4/8)
# loading U_TR/GT_surface_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_surface_temperature_24.npz
# loading U_T1/FC_surface_temperature_24_z64_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_surface_temperature_120.npz
# loading U_T1/FC_surface_temperature_120_z64_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_surface_temperature_240.npz
# loading U_T1/FC_surface_temperature_240_z64_past.npz
# Processing var U-Component of Wind at 850hPa (5/8)
# loading U_TR/GT_u_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_u_component_of_wind_24.npz
# loading U_T1/FC_u_component_of_wind_24_z64_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_u_component_of_wind_120.npz
# loading U_T1/FC_u_component_of_wind_120_z64_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_u_component_of_wind_240.npz
# loading U_T1/FC_u_component_of_wind_240_z64_past.npz
# Processing var V-Component of Wind at 850hPa (6/8)
# loading U_TR/GT_v_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_v_component_of_wind_24.npz
# loading U_T1/FC_v_component_of_wind_24_z64_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_v_component_of_wind_120.npz
# loading U_T1/FC_v_component_of_wind_120_z64_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_v_component_of_wind_240.npz
# loading U_T1/FC_v_component_of_wind_240_z64_past.npz
# Processing var Total Precipitation (7/8)
# loading U_TR/GT_total_precipitation_6hr.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_total_precipitation_6hr_24.npz
# loading U_T1/FC_total_precipitation_6hr_24_z64_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_total_precipitation_6hr_120.npz
# loading U_T1/FC_total_precipitation_6hr_120_z64_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_total_precipitation_6hr_240.npz
# loading U_T1/FC_total_precipitation_6hr_240_z64_past.npz
# Processing var Rel. Vorticity at 500hPa (8/8)
# loading U_TR/GT_relative_vorticity.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_relative_vorticity_24.npz
# loading U_T1/FC_relative_vorticity_24_z64_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_relative_vorticity_120.npz
# loading U_T1/FC_relative_vorticity_120_z64_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_relative_vorticity_240.npz
# loading U_T1/FC_relative_vorticity_240_z64_past.npz
# Evaluating model: UKESM z128 Multi-Mesh
# z128_future
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_z128-MM_future_dist_shift_all_vars_24_120_240.pdf
# Processing var Geopotential at 500hPa (1/8)
# loading U_TR/GT_geopotential_500.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_geopotential_500_24.npz
# loading U_T2/FC_geopotential_500_24_z128_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_geopotential_500_120.npz
# loading U_T2/FC_geopotential_500_120_z128_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_geopotential_500_240.npz
# loading U_T2/FC_geopotential_500_240_z128_future.npz
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_temperature_24.npz
# loading U_T2/FC_temperature_24_z128_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_temperature_120.npz
# loading U_T2/FC_temperature_120_z128_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_temperature_240.npz
# loading U_T2/FC_temperature_240_z128_future.npz
# Processing var Specific Humidity at 700hPa (3/8)
# loading U_TR/GT_specific_humidity.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_specific_humidity_24.npz
# loading U_T2/FC_specific_humidity_24_z128_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_specific_humidity_120.npz
# loading U_T2/FC_specific_humidity_120_z128_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_specific_humidity_240.npz
# loading U_T2/FC_specific_humidity_240_z128_future.npz
# Processing var 1.5m Temperature (4/8)
# loading U_TR/GT_surface_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_surface_temperature_24.npz
# loading U_T2/FC_surface_temperature_24_z128_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_surface_temperature_120.npz
# loading U_T2/FC_surface_temperature_120_z128_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_surface_temperature_240.npz
# loading U_T2/FC_surface_temperature_240_z128_future.npz
# Processing var U-Component of Wind at 850hPa (5/8)
# loading U_TR/GT_u_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_u_component_of_wind_24.npz
# loading U_T2/FC_u_component_of_wind_24_z128_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_u_component_of_wind_120.npz
# loading U_T2/FC_u_component_of_wind_120_z128_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_u_component_of_wind_240.npz
# loading U_T2/FC_u_component_of_wind_240_z128_future.npz
# Processing var V-Component of Wind at 850hPa (6/8)
# loading U_TR/GT_v_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_v_component_of_wind_24.npz
# loading U_T2/FC_v_component_of_wind_24_z128_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_v_component_of_wind_120.npz
# loading U_T2/FC_v_component_of_wind_120_z128_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_v_component_of_wind_240.npz
# loading U_T2/FC_v_component_of_wind_240_z128_future.npz
# Processing var Total Precipitation (7/8)
# loading U_TR/GT_total_precipitation_6hr.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_total_precipitation_6hr_24.npz
# loading U_T2/FC_total_precipitation_6hr_24_z128_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_total_precipitation_6hr_120.npz
# loading U_T2/FC_total_precipitation_6hr_120_z128_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_total_precipitation_6hr_240.npz
# loading U_T2/FC_total_precipitation_6hr_240_z128_future.npz
# Processing var Rel. Vorticity at 500hPa (8/8)
# loading U_TR/GT_relative_vorticity.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_relative_vorticity_24.npz
# loading U_T2/FC_relative_vorticity_24_z128_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_relative_vorticity_120.npz
# loading U_T2/FC_relative_vorticity_120_z128_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_relative_vorticity_240.npz
# loading U_T2/FC_relative_vorticity_240_z128_future.npz
# z128_past
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_z128-MM_hist_dist_shift_all_vars_24_120_240.pdf
# Processing var Geopotential at 500hPa (1/8)
# loading U_TR/GT_geopotential_500.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_geopotential_500_24.npz
# loading U_T1/FC_geopotential_500_24_z128_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_geopotential_500_120.npz
# loading U_T1/FC_geopotential_500_120_z128_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_geopotential_500_240.npz
# loading U_T1/FC_geopotential_500_240_z128_past.npz
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_temperature_24.npz
# loading U_T1/FC_temperature_24_z128_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_temperature_120.npz
# loading U_T1/FC_temperature_120_z128_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_temperature_240.npz
# loading U_T1/FC_temperature_240_z128_past.npz
# Processing var Specific Humidity at 700hPa (3/8)
# loading U_TR/GT_specific_humidity.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_specific_humidity_24.npz
# loading U_T1/FC_specific_humidity_24_z128_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_specific_humidity_120.npz
# loading U_T1/FC_specific_humidity_120_z128_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_specific_humidity_240.npz
# loading U_T1/FC_specific_humidity_240_z128_past.npz
# Processing var 1.5m Temperature (4/8)
# loading U_TR/GT_surface_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_surface_temperature_24.npz
# loading U_T1/FC_surface_temperature_24_z128_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_surface_temperature_120.npz
# loading U_T1/FC_surface_temperature_120_z128_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_surface_temperature_240.npz
# loading U_T1/FC_surface_temperature_240_z128_past.npz
# Processing var U-Component of Wind at 850hPa (5/8)
# loading U_TR/GT_u_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_u_component_of_wind_24.npz
# loading U_T1/FC_u_component_of_wind_24_z128_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_u_component_of_wind_120.npz
# loading U_T1/FC_u_component_of_wind_120_z128_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_u_component_of_wind_240.npz
# loading U_T1/FC_u_component_of_wind_240_z128_past.npz
# Processing var V-Component of Wind at 850hPa (6/8)
# loading U_TR/GT_v_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_v_component_of_wind_24.npz
# loading U_T1/FC_v_component_of_wind_24_z128_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_v_component_of_wind_120.npz
# loading U_T1/FC_v_component_of_wind_120_z128_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_v_component_of_wind_240.npz
# loading U_T1/FC_v_component_of_wind_240_z128_past.npz
# Processing var Total Precipitation (7/8)
# loading U_TR/GT_total_precipitation_6hr.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_total_precipitation_6hr_24.npz
# loading U_T1/FC_total_precipitation_6hr_24_z128_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_total_precipitation_6hr_120.npz
# loading U_T1/FC_total_precipitation_6hr_120_z128_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_total_precipitation_6hr_240.npz
# loading U_T1/FC_total_precipitation_6hr_240_z128_past.npz
# Processing var Rel. Vorticity at 500hPa (8/8)
# loading U_TR/GT_relative_vorticity.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_relative_vorticity_24.npz
# loading U_T1/FC_relative_vorticity_24_z128_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_relative_vorticity_120.npz
# loading U_T1/FC_relative_vorticity_120_z128_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_relative_vorticity_240.npz
# loading U_T1/FC_relative_vorticity_240_z128_past.npz
# Evaluating model: UKESM z256 Multi-Mesh
# z256_future
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_z256-MM_future_dist_shift_all_vars_24_120_240.pdf
# Processing var Geopotential at 500hPa (1/8)
# loading U_TR/GT_geopotential_500.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_geopotential_500_24.npz
# loading U_T2/FC_geopotential_500_24_z256_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_geopotential_500_120.npz
# loading U_T2/FC_geopotential_500_120_z256_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_geopotential_500_240.npz
# loading U_T2/FC_geopotential_500_240_z256_future.npz
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_temperature_24.npz
# loading U_T2/FC_temperature_24_z256_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_temperature_120.npz
# loading U_T2/FC_temperature_120_z256_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_temperature_240.npz
# loading U_T2/FC_temperature_240_z256_future.npz
# Processing var Specific Humidity at 700hPa (3/8)
# loading U_TR/GT_specific_humidity.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_specific_humidity_24.npz
# loading U_T2/FC_specific_humidity_24_z256_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_specific_humidity_120.npz
# loading U_T2/FC_specific_humidity_120_z256_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_specific_humidity_240.npz
# loading U_T2/FC_specific_humidity_240_z256_future.npz
# Processing var 1.5m Temperature (4/8)
# loading U_TR/GT_surface_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_surface_temperature_24.npz
# loading U_T2/FC_surface_temperature_24_z256_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_surface_temperature_120.npz
# loading U_T2/FC_surface_temperature_120_z256_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_surface_temperature_240.npz
# loading U_T2/FC_surface_temperature_240_z256_future.npz
# Processing var U-Component of Wind at 850hPa (5/8)
# loading U_TR/GT_u_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_u_component_of_wind_24.npz
# loading U_T2/FC_u_component_of_wind_24_z256_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_u_component_of_wind_120.npz
# loading U_T2/FC_u_component_of_wind_120_z256_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_u_component_of_wind_240.npz
# loading U_T2/FC_u_component_of_wind_240_z256_future.npz
# Processing var V-Component of Wind at 850hPa (6/8)
# loading U_TR/GT_v_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_v_component_of_wind_24.npz
# loading U_T2/FC_v_component_of_wind_24_z256_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_v_component_of_wind_120.npz
# loading U_T2/FC_v_component_of_wind_120_z256_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_v_component_of_wind_240.npz
# loading U_T2/FC_v_component_of_wind_240_z256_future.npz
# Processing var Total Precipitation (7/8)
# loading U_TR/GT_total_precipitation_6hr.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_total_precipitation_6hr_24.npz
# loading U_T2/FC_total_precipitation_6hr_24_z256_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_total_precipitation_6hr_120.npz
# loading U_T2/FC_total_precipitation_6hr_120_z256_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_total_precipitation_6hr_240.npz
# loading U_T2/FC_total_precipitation_6hr_240_z256_future.npz
# Processing var Rel. Vorticity at 500hPa (8/8)
# loading U_TR/GT_relative_vorticity.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_relative_vorticity_24.npz
# loading U_T2/FC_relative_vorticity_24_z256_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_relative_vorticity_120.npz
# loading U_T2/FC_relative_vorticity_120_z256_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_relative_vorticity_240.npz
# loading U_T2/FC_relative_vorticity_240_z256_future.npz
# z256_past
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_z256-MM_hist_dist_shift_all_vars_24_120_240.pdf
# Processing var Geopotential at 500hPa (1/8)
# loading U_TR/GT_geopotential_500.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_geopotential_500_24.npz
# loading U_T1/FC_geopotential_500_24_z256_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_geopotential_500_120.npz
# loading U_T1/FC_geopotential_500_120_z256_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_geopotential_500_240.npz
# loading U_T1/FC_geopotential_500_240_z256_past.npz
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_temperature_24.npz
# loading U_T1/FC_temperature_24_z256_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_temperature_120.npz
# loading U_T1/FC_temperature_120_z256_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_temperature_240.npz
# loading U_T1/FC_temperature_240_z256_past.npz
# Processing var Specific Humidity at 700hPa (3/8)
# loading U_TR/GT_specific_humidity.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_specific_humidity_24.npz
# loading U_T1/FC_specific_humidity_24_z256_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_specific_humidity_120.npz
# loading U_T1/FC_specific_humidity_120_z256_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_specific_humidity_240.npz
# loading U_T1/FC_specific_humidity_240_z256_past.npz
# Processing var 1.5m Temperature (4/8)
# loading U_TR/GT_surface_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_surface_temperature_24.npz
# loading U_T1/FC_surface_temperature_24_z256_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_surface_temperature_120.npz
# loading U_T1/FC_surface_temperature_120_z256_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_surface_temperature_240.npz
# loading U_T1/FC_surface_temperature_240_z256_past.npz
# Processing var U-Component of Wind at 850hPa (5/8)
# loading U_TR/GT_u_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_u_component_of_wind_24.npz
# loading U_T1/FC_u_component_of_wind_24_z256_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_u_component_of_wind_120.npz
# loading U_T1/FC_u_component_of_wind_120_z256_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_u_component_of_wind_240.npz
# loading U_T1/FC_u_component_of_wind_240_z256_past.npz
# Processing var V-Component of Wind at 850hPa (6/8)
# loading U_TR/GT_v_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_v_component_of_wind_24.npz
# loading U_T1/FC_v_component_of_wind_24_z256_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_v_component_of_wind_120.npz
# loading U_T1/FC_v_component_of_wind_120_z256_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_v_component_of_wind_240.npz
# loading U_T1/FC_v_component_of_wind_240_z256_past.npz
# Processing var Total Precipitation (7/8)
# loading U_TR/GT_total_precipitation_6hr.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_total_precipitation_6hr_24.npz
# loading U_T1/FC_total_precipitation_6hr_24_z256_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_total_precipitation_6hr_120.npz
# loading U_T1/FC_total_precipitation_6hr_120_z256_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_total_precipitation_6hr_240.npz
# loading U_T1/FC_total_precipitation_6hr_240_z256_past.npz
# Processing var Rel. Vorticity at 500hPa (8/8)
# loading U_TR/GT_relative_vorticity.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_relative_vorticity_24.npz
# loading U_T1/FC_relative_vorticity_24_z256_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_relative_vorticity_120.npz
# loading U_T1/FC_relative_vorticity_120_z256_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_relative_vorticity_240.npz
# loading U_T1/FC_relative_vorticity_240_z256_past.npz
# Evaluating model: UKESM z64 Hierarchical
# z64 hierarchical_future
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_z64-H_future_dist_shift_all_vars_24_120_240.pdf
# Processing var Geopotential at 500hPa (1/8)
# loading U_TR/GT_geopotential_500.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_geopotential_500_24.npz
# loading U_T2/FC_geopotential_500_24_z64 hierarchical_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_geopotential_500_120.npz
# loading U_T2/FC_geopotential_500_120_z64 hierarchical_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_geopotential_500_240.npz
# loading U_T2/FC_geopotential_500_240_z64 hierarchical_future.npz
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_temperature_24.npz
# loading U_T2/FC_temperature_24_z64 hierarchical_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_temperature_120.npz
# loading U_T2/FC_temperature_120_z64 hierarchical_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_temperature_240.npz
# loading U_T2/FC_temperature_240_z64 hierarchical_future.npz
# Processing var Specific Humidity at 700hPa (3/8)
# loading U_TR/GT_specific_humidity.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_specific_humidity_24.npz
# loading U_T2/FC_specific_humidity_24_z64 hierarchical_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_specific_humidity_120.npz
# loading U_T2/FC_specific_humidity_120_z64 hierarchical_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_specific_humidity_240.npz
# loading U_T2/FC_specific_humidity_240_z64 hierarchical_future.npz
# Processing var 1.5m Temperature (4/8)
# loading U_TR/GT_surface_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_surface_temperature_24.npz
# loading U_T2/FC_surface_temperature_24_z64 hierarchical_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_surface_temperature_120.npz
# loading U_T2/FC_surface_temperature_120_z64 hierarchical_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_surface_temperature_240.npz
# loading U_T2/FC_surface_temperature_240_z64 hierarchical_future.npz
# Processing var U-Component of Wind at 850hPa (5/8)
# loading U_TR/GT_u_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_u_component_of_wind_24.npz
# loading U_T2/FC_u_component_of_wind_24_z64 hierarchical_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_u_component_of_wind_120.npz
# loading U_T2/FC_u_component_of_wind_120_z64 hierarchical_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_u_component_of_wind_240.npz
# loading U_T2/FC_u_component_of_wind_240_z64 hierarchical_future.npz
# Processing var V-Component of Wind at 850hPa (6/8)
# loading U_TR/GT_v_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_v_component_of_wind_24.npz
# loading U_T2/FC_v_component_of_wind_24_z64 hierarchical_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_v_component_of_wind_120.npz
# loading U_T2/FC_v_component_of_wind_120_z64 hierarchical_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_v_component_of_wind_240.npz
# loading U_T2/FC_v_component_of_wind_240_z64 hierarchical_future.npz
# Processing var Total Precipitation (7/8)
# loading U_TR/GT_total_precipitation_6hr.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_total_precipitation_6hr_24.npz
# loading U_T2/FC_total_precipitation_6hr_24_z64 hierarchical_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_total_precipitation_6hr_120.npz
# loading U_T2/FC_total_precipitation_6hr_120_z64 hierarchical_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_total_precipitation_6hr_240.npz
# loading U_T2/FC_total_precipitation_6hr_240_z64 hierarchical_future.npz
# Processing var Rel. Vorticity at 500hPa (8/8)
# loading U_TR/GT_relative_vorticity.npz
#     Calculating distribution 1 of 3
# loading U_T2/GT_relative_vorticity_24.npz
# loading U_T2/FC_relative_vorticity_24_z64 hierarchical_future.npz
#     Calculating distribution 2 of 3
# loading U_T2/GT_relative_vorticity_120.npz
# loading U_T2/FC_relative_vorticity_120_z64 hierarchical_future.npz
#     Calculating distribution 3 of 3
# loading U_T2/GT_relative_vorticity_240.npz
# loading U_T2/FC_relative_vorticity_240_z64 hierarchical_future.npz
# z64 hierarchical_past
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_z64-H_hist_dist_shift_all_vars_24_120_240.pdf
# Processing var Geopotential at 500hPa (1/8)
# loading U_TR/GT_geopotential_500.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_geopotential_500_24.npz
# loading U_T1/FC_geopotential_500_24_z64 hierarchical_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_geopotential_500_120.npz
# loading U_T1/FC_geopotential_500_120_z64 hierarchical_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_geopotential_500_240.npz
# loading U_T1/FC_geopotential_500_240_z64 hierarchical_past.npz
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_temperature_24.npz
# loading U_T1/FC_temperature_24_z64 hierarchical_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_temperature_120.npz
# loading U_T1/FC_temperature_120_z64 hierarchical_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_temperature_240.npz
# loading U_T1/FC_temperature_240_z64 hierarchical_past.npz
# Processing var Specific Humidity at 700hPa (3/8)
# loading U_TR/GT_specific_humidity.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_specific_humidity_24.npz
# loading U_T1/FC_specific_humidity_24_z64 hierarchical_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_specific_humidity_120.npz
# loading U_T1/FC_specific_humidity_120_z64 hierarchical_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_specific_humidity_240.npz
# loading U_T1/FC_specific_humidity_240_z64 hierarchical_past.npz
# Processing var 1.5m Temperature (4/8)
# loading U_TR/GT_surface_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_surface_temperature_24.npz
# loading U_T1/FC_surface_temperature_24_z64 hierarchical_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_surface_temperature_120.npz
# loading U_T1/FC_surface_temperature_120_z64 hierarchical_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_surface_temperature_240.npz
# loading U_T1/FC_surface_temperature_240_z64 hierarchical_past.npz
# Processing var U-Component of Wind at 850hPa (5/8)
# loading U_TR/GT_u_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_u_component_of_wind_24.npz
# loading U_T1/FC_u_component_of_wind_24_z64 hierarchical_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_u_component_of_wind_120.npz
# loading U_T1/FC_u_component_of_wind_120_z64 hierarchical_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_u_component_of_wind_240.npz
# loading U_T1/FC_u_component_of_wind_240_z64 hierarchical_past.npz
# Processing var V-Component of Wind at 850hPa (6/8)
# loading U_TR/GT_v_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_v_component_of_wind_24.npz
# loading U_T1/FC_v_component_of_wind_24_z64 hierarchical_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_v_component_of_wind_120.npz
# loading U_T1/FC_v_component_of_wind_120_z64 hierarchical_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_v_component_of_wind_240.npz
# loading U_T1/FC_v_component_of_wind_240_z64 hierarchical_past.npz
# Processing var Total Precipitation (7/8)
# loading U_TR/GT_total_precipitation_6hr.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_total_precipitation_6hr_24.npz
# loading U_T1/FC_total_precipitation_6hr_24_z64 hierarchical_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_total_precipitation_6hr_120.npz
# loading U_T1/FC_total_precipitation_6hr_120_z64 hierarchical_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_total_precipitation_6hr_240.npz
# loading U_T1/FC_total_precipitation_6hr_240_z64 hierarchical_past.npz
# Processing var Rel. Vorticity at 500hPa (8/8)
# loading U_TR/GT_relative_vorticity.npz
#     Calculating distribution 1 of 3
# loading U_T1/GT_relative_vorticity_24.npz
# loading U_T1/FC_relative_vorticity_24_z64 hierarchical_past.npz
#     Calculating distribution 2 of 3
# loading U_T1/GT_relative_vorticity_120.npz
# loading U_T1/FC_relative_vorticity_120_z64 hierarchical_past.npz
#     Calculating distribution 3 of 3
# loading U_T1/GT_relative_vorticity_240.npz
# loading U_T1/FC_relative_vorticity_240_z64 hierarchical_past.npz

# %% [markdown]
# # Compute and plot - Interpolated

# %%
compute = False

model_short_names = ['z64-MM-interpolated','z256-MM-interpolated']
model_idx=0
num_models=len(model_short_names)


for model_idx in range(num_models):
    model_short_name = model_short_names[model_idx]
    selected_model_past=plot.PAST_MODELS_UKESM_HOLES_FILLED[model_idx]
    selected_model_future=plot.FUTURE_MODELS_UKESM_HOLES_FILLED[model_idx]
    print(f'Evaluating model: {selected_model_past["model_name"]}')
    
    base_save_folder_past = selected_model_past['plot_folder']
    base_save_folder_future = selected_model_future['plot_folder']

    for past in [False, True]:
    
        selected_model = selected_model_past if past else selected_model_future
        print(selected_model['id'])
            
        save_to=base_save_folder_past+'distribution_shift_forecast/' if past else base_save_folder_future+'distribution_shift_forecast/'
        save_to='/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/'
        save_name=f'UKESM_{model_short_name}_{"hist" if past else "future"}_dist_shift_all_vars_24_120_240.pdf'
        print(save_to+save_name)
        steps=[24, 5*24, 10*24]
        # steps=[6, 48]#, 5*24, 10*24]
        num_vars = len(plot.KEY_VARIABLES_UKESM)
        precip_p99=0
        
        fig, axes = plt.subplots(nrows=num_vars, ncols=len(steps), figsize=(4*len(steps),2*num_vars), sharex=False, sharey='row')
        create_folder_if_not_exists(save_to)
        for var_index in range(num_vars):
        # for var_index in [1]:
        # for var_index in range(6,7):
            
            display_name, unit, variable, plevel,_ = plot.KEY_VARIABLES_UKESM[var_index]
            plot_5_quant = variable in ['u_component_of_wind','v_component_of_wind','relative_vorticity']
            print(f'Processing var {display_name} ({var_index+1}/{num_vars})')
            train_dist_UKESM = dist.load_dist(variable, dataset='U',dataslice_name='TR', is_ground_truth=True)
            train_dist_UKESM['label'] = 'UI_TR'
            train_dist_UKESM['label_full'] = 'UI_TR'
                  
            for i, hours_into_future in enumerate(steps):
                print(f'    Calculating distribution {i+1} of {len(steps)}')
                ax = axes[var_index, i]
                
                if compute:
                    ukesm_past_forecasts = plot.open_zarr_ukesm(selected_model_past['forecasts'])
                    ukesm_future_forecasts = plot.open_zarr_ukesm(selected_model_future['forecasts'])
                    
                    ukesm_past_truth = plot.open_zarr_ukesm(selected_model_past['ground_truth'])
                    ukesm_future_truth = plot.open_zarr_ukesm(selected_model_future['ground_truth'])
                    
                    ds_test_truth, ds_test_forecast = dist.get_datasets_after(ukesm_past_truth, ukesm_past_forecasts, hours_into_future) if past else dist.get_datasets_after(ukesm_future_truth, ukesm_future_forecasts, hours_into_future) 
                    truth=ds_test_truth.sel(level=plevel)[variable] if plevel else ds_test_truth[variable]
                    forecast=ds_test_forecast.sel(level=plevel)[variable] if plevel else ds_test_forecast[variable]

                    mult = plot.get_multiplier_ukesm(variable)
                    if not mult == 1:
                        print(f"Multiplying data by {mult}")
                
                    # Select variable
                    truth = truth * mult
                    forecast = forecast * mult
    
                        
            
                    if plevel and plevel>500:
                        print(f"    Applying mask... ")
                        forecast = plot.get_masked_ukesm_data(forecast, plevel=plevel)
                        truth = plot.get_masked_ukesm_data(truth, plevel=plevel)
                    
                    forecast_dist=dist.calc_single_dist_with_nans(forecast)
                    # truth_dist=dist.calc_single_dist_with_nans(truth)

                    
                    forecast_dist['label'] = 'F'
                    forecast_dist['label_full'] = 'Forecast (F)'
                    
    
                    dist.precompute_and_save_distribution(forecast_dist, variable, dataset='U',dataslice_name='T1' if past else 'T2', is_ground_truth=False, rollout=hours_into_future, model_id=selected_model['id'])
                    # dist.precompute_and_save_distribution(forecast_dist, variable, dataset='U',dataslice_name='T1' if past else 'T2', is_ground_truth=False, rollout=hours_into_future, model_id=selected_model['id'], lower_bound=221.86797)
                
                else:
                    # truth_dist = dist.load_dist(variable, dataset='U',dataslice_name='T1' if past else 'T2', is_ground_truth=True, rollout=hours_into_future)
                    
                    forecast_dist = dist.load_dist(variable, dataset='U',dataslice_name='T1' if past else 'T2', is_ground_truth=False, rollout=hours_into_future, model_id=selected_model['id'])
                    
                truth_dist = dist.load_dist(variable, dataset='U',dataslice_name='T1' if past else 'T2', is_ground_truth=True, rollout=hours_into_future)
                if past:
                    truth_dist['label'] = 'UI_T1'
                    truth_dist['label_full'] = 'UI_T1'
                    forecast_dist['label'] = ''
                    forecast_dist['label_full'] = f'Forecast'
                else:
                    truth_dist['label'] = 'UI_T2'
                    truth_dist['label_full'] = 'UI_T2'
                    forecast_dist['label'] = ''
                    forecast_dist['label_full'] = f'Forecast'
                if (variable == 'total_precipitation_6hr') and i ==0:
                        precip_p99=truth_dist['p99']
                dist.plot_distributions_with_nans_on_axis(ax,
                                                     [truth_dist, forecast_dist],
                                                     background=[train_dist_UKESM],
                                                     bin_num=1000 if (variable == 'total_precipitation_6hr') else 500,
                                                     variable_name=display_name,
                                                     unit=unit,
                                                     title=f"{display_name} After {hours_into_future}h" if i==0 else f"After {hours_into_future}h",
                                                     plot_legend=False,
                                                     plot_5_quantile=plot_5_quant,plot_99_quant=(variable == 'total_precipitation_6hr'))
        
        min_x = [4.5, 225, -9999, 200, -9999,-9999,-9999,-9999]
        for var_index in range(num_vars):
            display_name, unit, variable, plevel, _ = plot.KEY_VARIABLES_UKESM[var_index]
            # collect all limits in this row
            xmins, xmaxs = [], []
            ymins, ymaxs = [], []
            for i, hours_into_future in enumerate(steps):
                ax = axes[var_index, i]
                xmin, xmax = ax.get_xlim()
                ymin, ymax = ax.get_ylim()
                xmins.append(xmin)
                xmaxs.append(xmax)
                ymins.append(ymin)
                ymaxs.append(ymax)
            # set same limits for all in row i
            row_xlim = (max(min(xmins),min_x[var_index]), max(xmaxs))
            if not variable == 'total_precipitation_6hr':
                row_xlim = dist.get_xlim(display_name, dataset='ukesm')
            row_ylim = (min(ymins), max(ymaxs))
            for i, hours_into_future in enumerate(steps):
                axes[var_index, i].set_xlim(row_xlim)
                if variable == 'total_precipitation_6hr':
                    axes[var_index, i].set_yscale('log')
                else:
                    axes[var_index, i].set_ylim(row_ylim)
                if i > 0:
                    axes[var_index, i].set_ylabel("")              # remove the label
                    axes[var_index, i].tick_params(labelleft=False)  # remove tick labels
                # axes[var_index, i].tick_params(bottom=True, top=False)
                # axes[var_index, i].xaxis.get_major_ticks()[0].set_visible(False)      # hide the leftmost tick
                # axes[var_index, i].xaxis.get_major_ticks()[-1].set_visible(False)     # hide the rightmost tick
                from matplotlib.ticker import ScalarFormatter
                offset = axes[var_index, i].xaxis.get_offset_text()
                offset.set_fontsize(9)
                
                # axes[var_index, i].xaxis.set_major_formatter(formatter)
                axes[var_index, i].ticklabel_format(axis="x", style="sci", scilimits=(-2, 3))
                if i ==0 and not 'precipitation' in display_name.lower():
                    axes[var_index, i].ticklabel_format(axis="y", style="sci", scilimits=(-2, 3))
                    offset = axes[var_index, i].yaxis.get_offset_text()
                    offset.set_x(-0.12)
                    offset.set_fontsize(9)
        fig.suptitle(f"UKESM {'UI_T1' if past else 'UI_T2'}:\n{model_short_name}", fontsize=16, y=0.96)
        from matplotlib.patches import Patch
        
        legend_elements = [
            Patch(facecolor="gray", edgecolor="none", label="Train UKESM Interpolated 1985–2010 (UI_TR)"),
            Patch(facecolor="C0", edgecolor="none", label="Test UKESM Interpolated 2011–2014 (UI_T1)" if past else "Test UKESM Interpolated 2097–2100 (UI_T2)")
        ]
        from matplotlib.lines import Line2D
        abbrev='U_T1' if past else 'U_T2'
        legend_elements += [
            Line2D([0], [0], color="C0",linestyle=(0, (1, 0)), lw=2, label=f"{abbrev} mean"),
            Line2D([0], [0], color="C0", lw=2, linestyle=(0, (1, 3)), label=f"{abbrev} 95th % (99.9th % for Precipitation)"),
            Line2D([0], [0], color="C0", lw=2, linestyle=(0, (5, 3)), label=f"{abbrev} 5th %")
        ]
            
        
        fig.legend(
            handles=legend_elements,
            loc="upper left",
            bbox_to_anchor=(0.04, 0.99),
        )

        
        legend_elements = [
            Patch(facecolor="C1", edgecolor="none", label="Forecast 2011–2014" if past else "Forecast 2097–2100")
        ]

        legend_elements += [
            Line2D([0], [0], color="C1",linestyle=(0, (1, 0)), lw=2, label="Forecast mean"),
            Line2D([0], [0], color="C1", lw=2, linestyle=(0, (1, 3)), label="Forecast 95th % (99.9th % for Precipitation)"),
            Line2D([0], [0], color="C1", lw=2, linestyle=(0, (5, 3)), label="Forecast 5th %")
        ]
            
        
        fig.legend(
            handles=legend_elements,
            loc="upper right",
            bbox_to_anchor=(0.98, 0.99),
        )
        
        fig.tight_layout(rect=[0, 0, 1, 0.96])
        plt.savefig(save_to+save_name, bbox_inches="tight", dpi=600)
        plt.close()
# Out:
# Evaluating model: UKESM z64 Multi-Mesh Interpolated
# z64_future_interpolated
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_z64-MM-interpolated_future_dist_shift_all_vars_24_120_240.pdf
# Processing var Geopotential at 500hPa (1/8)
# loading U_TR/GT_geopotential_500.npz
#     Calculating distribution 1 of 3
# loading U_T2/FC_geopotential_500_24_z64_future_interpolated.npz
# loading U_T2/GT_geopotential_500_24.npz
#     Calculating distribution 2 of 3
# loading U_T2/FC_geopotential_500_120_z64_future_interpolated.npz
# loading U_T2/GT_geopotential_500_120.npz
#     Calculating distribution 3 of 3
# loading U_T2/FC_geopotential_500_240_z64_future_interpolated.npz
# loading U_T2/GT_geopotential_500_240.npz
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T2/FC_temperature_24_z64_future_interpolated.npz
# loading U_T2/GT_temperature_24.npz
#     Calculating distribution 2 of 3
# loading U_T2/FC_temperature_120_z64_future_interpolated.npz
# loading U_T2/GT_temperature_120.npz
#     Calculating distribution 3 of 3
# loading U_T2/FC_temperature_240_z64_future_interpolated.npz
# loading U_T2/GT_temperature_240.npz
# Processing var Specific Humidity at 700hPa (3/8)
# loading U_TR/GT_specific_humidity.npz
#     Calculating distribution 1 of 3
# loading U_T2/FC_specific_humidity_24_z64_future_interpolated.npz
# loading U_T2/GT_specific_humidity_24.npz
#     Calculating distribution 2 of 3
# loading U_T2/FC_specific_humidity_120_z64_future_interpolated.npz
# loading U_T2/GT_specific_humidity_120.npz
#     Calculating distribution 3 of 3
# loading U_T2/FC_specific_humidity_240_z64_future_interpolated.npz
# loading U_T2/GT_specific_humidity_240.npz
# Processing var 1.5m Temperature (4/8)
# loading U_TR/GT_surface_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T2/FC_surface_temperature_24_z64_future_interpolated.npz
# loading U_T2/GT_surface_temperature_24.npz
#     Calculating distribution 2 of 3
# loading U_T2/FC_surface_temperature_120_z64_future_interpolated.npz
# loading U_T2/GT_surface_temperature_120.npz
#     Calculating distribution 3 of 3
# loading U_T2/FC_surface_temperature_240_z64_future_interpolated.npz
# loading U_T2/GT_surface_temperature_240.npz
# Processing var U-Component of Wind at 850hPa (5/8)
# loading U_TR/GT_u_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T2/FC_u_component_of_wind_24_z64_future_interpolated.npz
# loading U_T2/GT_u_component_of_wind_24.npz
#     Calculating distribution 2 of 3
# loading U_T2/FC_u_component_of_wind_120_z64_future_interpolated.npz
# loading U_T2/GT_u_component_of_wind_120.npz
#     Calculating distribution 3 of 3
# loading U_T2/FC_u_component_of_wind_240_z64_future_interpolated.npz
# loading U_T2/GT_u_component_of_wind_240.npz
# Processing var V-Component of Wind at 850hPa (6/8)
# loading U_TR/GT_v_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T2/FC_v_component_of_wind_24_z64_future_interpolated.npz
# loading U_T2/GT_v_component_of_wind_24.npz
#     Calculating distribution 2 of 3
# loading U_T2/FC_v_component_of_wind_120_z64_future_interpolated.npz
# loading U_T2/GT_v_component_of_wind_120.npz
#     Calculating distribution 3 of 3
# loading U_T2/FC_v_component_of_wind_240_z64_future_interpolated.npz
# loading U_T2/GT_v_component_of_wind_240.npz
# Processing var Total Precipitation (7/8)
# loading U_TR/GT_total_precipitation_6hr.npz
#     Calculating distribution 1 of 3
# loading U_T2/FC_total_precipitation_6hr_24_z64_future_interpolated.npz
# loading U_T2/GT_total_precipitation_6hr_24.npz
#     Calculating distribution 2 of 3
# loading U_T2/FC_total_precipitation_6hr_120_z64_future_interpolated.npz
# loading U_T2/GT_total_precipitation_6hr_120.npz
#     Calculating distribution 3 of 3
# loading U_T2/FC_total_precipitation_6hr_240_z64_future_interpolated.npz
# loading U_T2/GT_total_precipitation_6hr_240.npz
# Processing var Rel. Vorticity at 500hPa (8/8)
# loading U_TR/GT_relative_vorticity.npz
#     Calculating distribution 1 of 3
# loading U_T2/FC_relative_vorticity_24_z64_future_interpolated.npz
# loading U_T2/GT_relative_vorticity_24.npz
#     Calculating distribution 2 of 3
# loading U_T2/FC_relative_vorticity_120_z64_future_interpolated.npz
# loading U_T2/GT_relative_vorticity_120.npz
#     Calculating distribution 3 of 3
# loading U_T2/FC_relative_vorticity_240_z64_future_interpolated.npz
# loading U_T2/GT_relative_vorticity_240.npz
# z64_past_interpolated
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_z64-MM-interpolated_hist_dist_shift_all_vars_24_120_240.pdf
# Processing var Geopotential at 500hPa (1/8)
# loading U_TR/GT_geopotential_500.npz
#     Calculating distribution 1 of 3
# loading U_T1/FC_geopotential_500_24_z64_past_interpolated.npz
# loading U_T1/GT_geopotential_500_24.npz
#     Calculating distribution 2 of 3
# loading U_T1/FC_geopotential_500_120_z64_past_interpolated.npz
# loading U_T1/GT_geopotential_500_120.npz
#     Calculating distribution 3 of 3
# loading U_T1/FC_geopotential_500_240_z64_past_interpolated.npz
# loading U_T1/GT_geopotential_500_240.npz
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T1/FC_temperature_24_z64_past_interpolated.npz
# loading U_T1/GT_temperature_24.npz
#     Calculating distribution 2 of 3
# loading U_T1/FC_temperature_120_z64_past_interpolated.npz
# loading U_T1/GT_temperature_120.npz
#     Calculating distribution 3 of 3
# loading U_T1/FC_temperature_240_z64_past_interpolated.npz
# loading U_T1/GT_temperature_240.npz
# Processing var Specific Humidity at 700hPa (3/8)
# loading U_TR/GT_specific_humidity.npz
#     Calculating distribution 1 of 3
# loading U_T1/FC_specific_humidity_24_z64_past_interpolated.npz
# loading U_T1/GT_specific_humidity_24.npz
#     Calculating distribution 2 of 3
# loading U_T1/FC_specific_humidity_120_z64_past_interpolated.npz
# loading U_T1/GT_specific_humidity_120.npz
#     Calculating distribution 3 of 3
# loading U_T1/FC_specific_humidity_240_z64_past_interpolated.npz
# loading U_T1/GT_specific_humidity_240.npz
# Processing var 1.5m Temperature (4/8)
# loading U_TR/GT_surface_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T1/FC_surface_temperature_24_z64_past_interpolated.npz
# loading U_T1/GT_surface_temperature_24.npz
#     Calculating distribution 2 of 3
# loading U_T1/FC_surface_temperature_120_z64_past_interpolated.npz
# loading U_T1/GT_surface_temperature_120.npz
#     Calculating distribution 3 of 3
# loading U_T1/FC_surface_temperature_240_z64_past_interpolated.npz
# loading U_T1/GT_surface_temperature_240.npz
# Processing var U-Component of Wind at 850hPa (5/8)
# loading U_TR/GT_u_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T1/FC_u_component_of_wind_24_z64_past_interpolated.npz
# loading U_T1/GT_u_component_of_wind_24.npz
#     Calculating distribution 2 of 3
# loading U_T1/FC_u_component_of_wind_120_z64_past_interpolated.npz
# loading U_T1/GT_u_component_of_wind_120.npz
#     Calculating distribution 3 of 3
# loading U_T1/FC_u_component_of_wind_240_z64_past_interpolated.npz
# loading U_T1/GT_u_component_of_wind_240.npz
# Processing var V-Component of Wind at 850hPa (6/8)
# loading U_TR/GT_v_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T1/FC_v_component_of_wind_24_z64_past_interpolated.npz
# loading U_T1/GT_v_component_of_wind_24.npz
#     Calculating distribution 2 of 3
# loading U_T1/FC_v_component_of_wind_120_z64_past_interpolated.npz
# loading U_T1/GT_v_component_of_wind_120.npz
#     Calculating distribution 3 of 3
# loading U_T1/FC_v_component_of_wind_240_z64_past_interpolated.npz
# loading U_T1/GT_v_component_of_wind_240.npz
# Processing var Total Precipitation (7/8)
# loading U_TR/GT_total_precipitation_6hr.npz
#     Calculating distribution 1 of 3
# loading U_T1/FC_total_precipitation_6hr_24_z64_past_interpolated.npz
# loading U_T1/GT_total_precipitation_6hr_24.npz
#     Calculating distribution 2 of 3
# loading U_T1/FC_total_precipitation_6hr_120_z64_past_interpolated.npz
# loading U_T1/GT_total_precipitation_6hr_120.npz
#     Calculating distribution 3 of 3
# loading U_T1/FC_total_precipitation_6hr_240_z64_past_interpolated.npz
# loading U_T1/GT_total_precipitation_6hr_240.npz
# Processing var Rel. Vorticity at 500hPa (8/8)
# loading U_TR/GT_relative_vorticity.npz
#     Calculating distribution 1 of 3
# loading U_T1/FC_relative_vorticity_24_z64_past_interpolated.npz
# loading U_T1/GT_relative_vorticity_24.npz
#     Calculating distribution 2 of 3
# loading U_T1/FC_relative_vorticity_120_z64_past_interpolated.npz
# loading U_T1/GT_relative_vorticity_120.npz
#     Calculating distribution 3 of 3
# loading U_T1/FC_relative_vorticity_240_z64_past_interpolated.npz
# loading U_T1/GT_relative_vorticity_240.npz
# Evaluating model: UKESM z256 Multi-Mesh Interpolated
# z256_future_interpolated
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_z256-MM-interpolated_future_dist_shift_all_vars_24_120_240.pdf
# Processing var Geopotential at 500hPa (1/8)
# loading U_TR/GT_geopotential_500.npz
#     Calculating distribution 1 of 3
# loading U_T2/FC_geopotential_500_24_z256_future_interpolated.npz
# loading U_T2/GT_geopotential_500_24.npz
#     Calculating distribution 2 of 3
# loading U_T2/FC_geopotential_500_120_z256_future_interpolated.npz
# loading U_T2/GT_geopotential_500_120.npz
#     Calculating distribution 3 of 3
# loading U_T2/FC_geopotential_500_240_z256_future_interpolated.npz
# loading U_T2/GT_geopotential_500_240.npz
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T2/FC_temperature_24_z256_future_interpolated.npz
# loading U_T2/GT_temperature_24.npz
#     Calculating distribution 2 of 3
# loading U_T2/FC_temperature_120_z256_future_interpolated.npz
# loading U_T2/GT_temperature_120.npz
#     Calculating distribution 3 of 3
# loading U_T2/FC_temperature_240_z256_future_interpolated.npz
# loading U_T2/GT_temperature_240.npz
# Processing var Specific Humidity at 700hPa (3/8)
# loading U_TR/GT_specific_humidity.npz
#     Calculating distribution 1 of 3
# loading U_T2/FC_specific_humidity_24_z256_future_interpolated.npz
# loading U_T2/GT_specific_humidity_24.npz
#     Calculating distribution 2 of 3
# loading U_T2/FC_specific_humidity_120_z256_future_interpolated.npz
# loading U_T2/GT_specific_humidity_120.npz
#     Calculating distribution 3 of 3
# loading U_T2/FC_specific_humidity_240_z256_future_interpolated.npz
# loading U_T2/GT_specific_humidity_240.npz
# Processing var 1.5m Temperature (4/8)
# loading U_TR/GT_surface_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T2/FC_surface_temperature_24_z256_future_interpolated.npz
# loading U_T2/GT_surface_temperature_24.npz
#     Calculating distribution 2 of 3
# loading U_T2/FC_surface_temperature_120_z256_future_interpolated.npz
# loading U_T2/GT_surface_temperature_120.npz
#     Calculating distribution 3 of 3
# loading U_T2/FC_surface_temperature_240_z256_future_interpolated.npz
# loading U_T2/GT_surface_temperature_240.npz
# Processing var U-Component of Wind at 850hPa (5/8)
# loading U_TR/GT_u_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T2/FC_u_component_of_wind_24_z256_future_interpolated.npz
# loading U_T2/GT_u_component_of_wind_24.npz
#     Calculating distribution 2 of 3
# loading U_T2/FC_u_component_of_wind_120_z256_future_interpolated.npz
# loading U_T2/GT_u_component_of_wind_120.npz
#     Calculating distribution 3 of 3
# loading U_T2/FC_u_component_of_wind_240_z256_future_interpolated.npz
# loading U_T2/GT_u_component_of_wind_240.npz
# Processing var V-Component of Wind at 850hPa (6/8)
# loading U_TR/GT_v_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T2/FC_v_component_of_wind_24_z256_future_interpolated.npz
# loading U_T2/GT_v_component_of_wind_24.npz
#     Calculating distribution 2 of 3
# loading U_T2/FC_v_component_of_wind_120_z256_future_interpolated.npz
# loading U_T2/GT_v_component_of_wind_120.npz
#     Calculating distribution 3 of 3
# loading U_T2/FC_v_component_of_wind_240_z256_future_interpolated.npz
# loading U_T2/GT_v_component_of_wind_240.npz
# Processing var Total Precipitation (7/8)
# loading U_TR/GT_total_precipitation_6hr.npz
#     Calculating distribution 1 of 3
# loading U_T2/FC_total_precipitation_6hr_24_z256_future_interpolated.npz
# loading U_T2/GT_total_precipitation_6hr_24.npz
#     Calculating distribution 2 of 3
# loading U_T2/FC_total_precipitation_6hr_120_z256_future_interpolated.npz
# loading U_T2/GT_total_precipitation_6hr_120.npz
#     Calculating distribution 3 of 3
# loading U_T2/FC_total_precipitation_6hr_240_z256_future_interpolated.npz
# loading U_T2/GT_total_precipitation_6hr_240.npz
# Processing var Rel. Vorticity at 500hPa (8/8)
# loading U_TR/GT_relative_vorticity.npz
#     Calculating distribution 1 of 3
# loading U_T2/FC_relative_vorticity_24_z256_future_interpolated.npz
# loading U_T2/GT_relative_vorticity_24.npz
#     Calculating distribution 2 of 3
# loading U_T2/FC_relative_vorticity_120_z256_future_interpolated.npz
# loading U_T2/GT_relative_vorticity_120.npz
#     Calculating distribution 3 of 3
# loading U_T2/FC_relative_vorticity_240_z256_future_interpolated.npz
# loading U_T2/GT_relative_vorticity_240.npz
# z256_past_interpolated
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_z256-MM-interpolated_hist_dist_shift_all_vars_24_120_240.pdf
# Processing var Geopotential at 500hPa (1/8)
# loading U_TR/GT_geopotential_500.npz
#     Calculating distribution 1 of 3
# loading U_T1/FC_geopotential_500_24_z256_past_interpolated.npz
# loading U_T1/GT_geopotential_500_24.npz
#     Calculating distribution 2 of 3
# loading U_T1/FC_geopotential_500_120_z256_past_interpolated.npz
# loading U_T1/GT_geopotential_500_120.npz
#     Calculating distribution 3 of 3
# loading U_T1/FC_geopotential_500_240_z256_past_interpolated.npz
# loading U_T1/GT_geopotential_500_240.npz
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T1/FC_temperature_24_z256_past_interpolated.npz
# loading U_T1/GT_temperature_24.npz
#     Calculating distribution 2 of 3
# loading U_T1/FC_temperature_120_z256_past_interpolated.npz
# loading U_T1/GT_temperature_120.npz
#     Calculating distribution 3 of 3
# loading U_T1/FC_temperature_240_z256_past_interpolated.npz
# loading U_T1/GT_temperature_240.npz
# Processing var Specific Humidity at 700hPa (3/8)
# loading U_TR/GT_specific_humidity.npz
#     Calculating distribution 1 of 3
# loading U_T1/FC_specific_humidity_24_z256_past_interpolated.npz
# loading U_T1/GT_specific_humidity_24.npz
#     Calculating distribution 2 of 3
# loading U_T1/FC_specific_humidity_120_z256_past_interpolated.npz
# loading U_T1/GT_specific_humidity_120.npz
#     Calculating distribution 3 of 3
# loading U_T1/FC_specific_humidity_240_z256_past_interpolated.npz
# loading U_T1/GT_specific_humidity_240.npz
# Processing var 1.5m Temperature (4/8)
# loading U_TR/GT_surface_temperature.npz
#     Calculating distribution 1 of 3
# loading U_T1/FC_surface_temperature_24_z256_past_interpolated.npz
# loading U_T1/GT_surface_temperature_24.npz
#     Calculating distribution 2 of 3
# loading U_T1/FC_surface_temperature_120_z256_past_interpolated.npz
# loading U_T1/GT_surface_temperature_120.npz
#     Calculating distribution 3 of 3
# loading U_T1/FC_surface_temperature_240_z256_past_interpolated.npz
# loading U_T1/GT_surface_temperature_240.npz
# Processing var U-Component of Wind at 850hPa (5/8)
# loading U_TR/GT_u_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T1/FC_u_component_of_wind_24_z256_past_interpolated.npz
# loading U_T1/GT_u_component_of_wind_24.npz
#     Calculating distribution 2 of 3
# loading U_T1/FC_u_component_of_wind_120_z256_past_interpolated.npz
# loading U_T1/GT_u_component_of_wind_120.npz
#     Calculating distribution 3 of 3
# loading U_T1/FC_u_component_of_wind_240_z256_past_interpolated.npz
# loading U_T1/GT_u_component_of_wind_240.npz
# Processing var V-Component of Wind at 850hPa (6/8)
# loading U_TR/GT_v_component_of_wind.npz
#     Calculating distribution 1 of 3
# loading U_T1/FC_v_component_of_wind_24_z256_past_interpolated.npz
# loading U_T1/GT_v_component_of_wind_24.npz
#     Calculating distribution 2 of 3
# loading U_T1/FC_v_component_of_wind_120_z256_past_interpolated.npz
# loading U_T1/GT_v_component_of_wind_120.npz
#     Calculating distribution 3 of 3
# loading U_T1/FC_v_component_of_wind_240_z256_past_interpolated.npz
# loading U_T1/GT_v_component_of_wind_240.npz
# Processing var Total Precipitation (7/8)
# loading U_TR/GT_total_precipitation_6hr.npz
#     Calculating distribution 1 of 3
# loading U_T1/FC_total_precipitation_6hr_24_z256_past_interpolated.npz
# loading U_T1/GT_total_precipitation_6hr_24.npz
#     Calculating distribution 2 of 3
# loading U_T1/FC_total_precipitation_6hr_120_z256_past_interpolated.npz
# loading U_T1/GT_total_precipitation_6hr_120.npz
#     Calculating distribution 3 of 3
# loading U_T1/FC_total_precipitation_6hr_240_z256_past_interpolated.npz
# loading U_T1/GT_total_precipitation_6hr_240.npz
# Processing var Rel. Vorticity at 500hPa (8/8)
# loading U_TR/GT_relative_vorticity.npz
#     Calculating distribution 1 of 3
# loading U_T1/FC_relative_vorticity_24_z256_past_interpolated.npz
# loading U_T1/GT_relative_vorticity_24.npz
#     Calculating distribution 2 of 3
# loading U_T1/FC_relative_vorticity_120_z256_past_interpolated.npz
# loading U_T1/GT_relative_vorticity_120.npz
#     Calculating distribution 3 of 3
# loading U_T1/FC_relative_vorticity_240_z256_past_interpolated.npz
# loading U_T1/GT_relative_vorticity_240.npz

# %% [markdown]
# # Only Compute - Non-Interpolated

# %%
compute = True

model_short_names = ['z64-MM','z128-MM','z256-MM','z64-H']
model_idx=0



for model_idx in range(4):
    model_short_name = model_short_names[model_idx]
    selected_model_past=plot.PAST_MODELS_UKESM[model_idx]
    selected_model_future=plot.FUTURE_MODELS_UKESM[model_idx]
    print(f'Evaluating model: {selected_model_past["model_name"]}')
    
    base_save_folder_past = selected_model_past['plot_folder']
    base_save_folder_future = selected_model_future['plot_folder']

    for past in [False, True]:
    
        selected_model = selected_model_past if past else selected_model_future
        print(selected_model['id'])
            
        save_to=base_save_folder_past+'distribution_shift_forecast/' if past else base_save_folder_future+'distribution_shift_forecast/'
        save_to='/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/'
        save_name=f'UKESM_{model_short_name}_{"hist" if past else "future"}_dist_shift_all_vars_24_120_240.pdf'
        print(save_to+save_name)
        steps=[24, 5*24, 10*24]
        # steps=[6, 48]#, 5*24, 10*24]
        num_vars = len(plot.KEY_VARIABLES_UKESM)
        precip_p99=0
        
        create_folder_if_not_exists(save_to)
        for var_index in [1]:
        # for var_index in range(6,7):
            
            display_name, unit, variable, plevel,_ = plot.KEY_VARIABLES_UKESM[var_index]
            plot_5_quant = variable in ['u_component_of_wind','v_component_of_wind','relative_vorticity']
            print(f'Processing var {display_name} ({var_index+1}/{num_vars})')
            train_dist_UKESM = dist.load_dist(variable, dataset='U',dataslice_name='TR', is_ground_truth=True)
            train_dist_UKESM['label'] = 'U_TR'
            train_dist_UKESM['label_full'] = 'Train UKESM 1985-2010 (U_TR)'
                  
            for i, hours_into_future in enumerate(steps):
                print(f'    Calculating distribution {i+1} of {len(steps)}')
                
                if compute:
                    ukesm_past_forecasts = plot.open_zarr_ukesm(selected_model_past['forecasts'])
                    ukesm_future_forecasts = plot.open_zarr_ukesm(selected_model_future['forecasts'])
                    
                    ukesm_past_truth = plot.open_zarr_ukesm(selected_model_past['ground_truth'])
                    ukesm_future_truth = plot.open_zarr_ukesm(selected_model_future['ground_truth'])
                    
                    ds_test_truth, ds_test_forecast = dist.get_datasets_after(ukesm_past_truth, ukesm_past_forecasts, hours_into_future) if past else dist.get_datasets_after(ukesm_future_truth, ukesm_future_forecasts, hours_into_future) 
                    truth=ds_test_truth.sel(level=plevel)[variable] if plevel else ds_test_truth[variable]
                    forecast=ds_test_forecast.sel(level=plevel)[variable] if plevel else ds_test_forecast[variable]

                    mult = plot.get_multiplier_ukesm(variable)
                    if not mult == 1:
                        print(f"Multiplying data by {mult}")
                
                    # Select variable
                    truth = truth * mult
                    forecast = forecast * mult
    
                        
            
                    if plevel and plevel>500:
                        print(f"    Applying mask... ")
                        forecast = plot.get_masked_ukesm_data(forecast, plevel=plevel)
                        truth = plot.get_masked_ukesm_data(truth, plevel=plevel)
                    
                    forecast_dist=dist.calc_single_dist_with_nans(forecast)
                    # truth_dist=dist.calc_single_dist_with_nans(truth)

                    print(f'Forecast: {len(forecast_dist["vals"])}')
                    # print(f'GT: {len(truth_dist["vals"])}')

                    
                    forecast_dist['label'] = 'F'
                    forecast_dist['label_full'] = 'Forecast (F)'
                    
    
                    dist.precompute_and_save_distribution(forecast_dist, variable, dataset='U',dataslice_name='T1' if past else 'T2', is_ground_truth=False, rollout=hours_into_future, model_id=selected_model['id'], lower_bound=221.86797)
                    # dist.precompute_and_save_distribution(truth_dist, variable, dataset='U',dataslice_name='T1' if past else 'T2', is_ground_truth=True, rollout=hours_into_future)
# Out:
# Evaluating model: UKESM z64 Multi-Mesh
# z64_future
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_z64-MM_future_dist_shift_all_vars_24_120_240.pdf
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 3
#     Starting with a step length of 3 (==24 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 232.87353515625
# Percentage removed: 0.00000%
#     Calculating distribution 2 of 3
#     Starting with a step length of 19 (==120 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: -107.7716064453125
# Percentage removed: 0.08667%
#     Calculating distribution 3 of 3
#     Starting with a step length of 39 (==240 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: -667.7435302734375
# Percentage removed: 1.28196%
# z64_past
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_z64-MM_hist_dist_shift_all_vars_24_120_240.pdf
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 3
#     Starting with a step length of 3 (==24 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 224.55828857421875
# Percentage removed: 0.00000%
#     Calculating distribution 2 of 3
#     Starting with a step length of 19 (==120 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 215.8539276123047
# Percentage removed: 0.00001%
#     Calculating distribution 3 of 3
#     Starting with a step length of 39 (==240 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 201.67257690429688
# Percentage removed: 0.00186%
# Evaluating model: UKESM z128 Multi-Mesh
# z128_future
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_z128-MM_future_dist_shift_all_vars_24_120_240.pdf
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 3
#     Starting with a step length of 3 (==24 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 191.38662719726562
# Percentage removed: 0.00001%
#     Calculating distribution 2 of 3
#     Starting with a step length of 19 (==120 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 128.57571411132812
# Percentage removed: 0.00041%
#     Calculating distribution 3 of 3
#     Starting with a step length of 39 (==240 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 157.35910034179688
# Percentage removed: 0.01300%
# z128_past
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_z128-MM_hist_dist_shift_all_vars_24_120_240.pdf
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 3
#     Starting with a step length of 3 (==24 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 169.44174194335938
# Percentage removed: 0.00005%
#     Calculating distribution 2 of 3
#     Starting with a step length of 19 (==120 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 166.75711059570312
# Percentage removed: 0.00054%
#     Calculating distribution 3 of 3
#     Starting with a step length of 39 (==240 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 160.20135498046875
# Percentage removed: 0.00227%
# Evaluating model: UKESM z256 Multi-Mesh
# z256_future
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_z256-MM_future_dist_shift_all_vars_24_120_240.pdf
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 3
#     Starting with a step length of 3 (==24 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 199.4833221435547
# Percentage removed: 0.00002%
#     Calculating distribution 2 of 3
#     Starting with a step length of 19 (==120 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 162.78701782226562
# Percentage removed: 0.00014%
#     Calculating distribution 3 of 3
#     Starting with a step length of 39 (==240 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 165.14425659179688
# Percentage removed: 0.00020%
# z256_past
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_z256-MM_hist_dist_shift_all_vars_24_120_240.pdf
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 3
#     Starting with a step length of 3 (==24 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 175.13003540039062
# Percentage removed: 0.00006%
#     Calculating distribution 2 of 3
#     Starting with a step length of 19 (==120 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 139.1153564453125
# Percentage removed: 0.00020%
#     Calculating distribution 3 of 3
#     Starting with a step length of 39 (==240 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 144.06753540039062
# Percentage removed: 0.00052%
# Evaluating model: UKESM z64 Hierarchical
# z64 hierarchical_future
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_z64-H_future_dist_shift_all_vars_24_120_240.pdf
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 3
#     Starting with a step length of 3 (==24 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 200.20693969726562
# Percentage removed: 0.00004%
#     Calculating distribution 2 of 3
#     Starting with a step length of 19 (==120 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 166.81546020507812
# Percentage removed: 0.00053%
#     Calculating distribution 3 of 3
#     Starting with a step length of 39 (==240 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: -61.28765869140625
# Percentage removed: 0.04333%
# z64 hierarchical_past
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_z64-H_hist_dist_shift_all_vars_24_120_240.pdf
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 3
#     Starting with a step length of 3 (==24 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 176.8923797607422
# Percentage removed: 0.00012%
#     Calculating distribution 2 of 3
#     Starting with a step length of 19 (==120 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 143.9813995361328
# Percentage removed: 0.00105%
#     Calculating distribution 3 of 3
#     Starting with a step length of 39 (==240 hours)
#     Applying mask...
# Forecast: 19825520
# Lowest number: 132.0819854736328
# Percentage removed: 0.00229%

# %% [markdown]
# # Plot hist and future next to each other

# %%
compute = False

model_short_names = ['z64-MM','z128-MM','z256-MM','z64-H']
model_idx=0

save_to='/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/'
save_name='UKESM_dist_shift_geopotential_multiple_models_past_future_24_120_240.pdf'
print(save_to+save_name)
steps=5*24
# steps=[6, 48]#, 5*24, 10*24]
num_vars = len(plot.KEY_VARIABLES_UKESM)
precip_p99=0
nrows=3
ncols=2

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(6*ncols,3*nrows), sharex=False, sharey=False)
create_folder_if_not_exists(save_to)

for j, model_idx in enumerate([0,2,3]):
    model_short_name = model_short_names[model_idx]
    selected_model_past=plot.PAST_MODELS_UKESM[model_idx]
    selected_model_future=plot.FUTURE_MODELS_UKESM[model_idx]
    print(f'Evaluating model: {selected_model_past["model_name"]}')
    
    base_save_folder_past = selected_model_past['plot_folder']
    base_save_folder_future = selected_model_future['plot_folder']
    compute = False


    print(selected_model_past['id'])
    
    # for var_index in range(6,7):
    var_index=0
    display_name, unit, variable, plevel,_ = plot.KEY_VARIABLES_UKESM[var_index]
    plot_5_quant = variable in ['u_component_of_wind','v_component_of_wind','relative_vorticity']
    print(f'Processing var {display_name} ({var_index+1}/{num_vars})')
    train_dist_UKESM = dist.load_dist(variable, dataset='U',dataslice_name='TR', is_ground_truth=True)
    train_dist_UKESM['label'] = 'U_TR'
    train_dist_UKESM['label_full'] = 'Train UKESM 1985-2010 (U_TR)'
            
    for i, past in enumerate([True, False]):
        print(f'    Calculating distribution {i+1} of {2}')
        hours_into_future = steps
        ax = axes[j, i]
        selected_model = selected_model_past if past else selected_model_future
        
        truth_dist = dist.load_dist(variable, dataset='U',dataslice_name='T1' if past else 'T2', is_ground_truth=True, rollout=hours_into_future)
        forecast_dist = dist.load_dist(variable, dataset='U',dataslice_name='T1' if past else 'T2', is_ground_truth=False, rollout=hours_into_future, model_id=selected_model['id'])
        # if variable == 'total_precipitation_6hr':
        #     for data in [truth_dist, forecast_dist]:
        #         data['hist']  /= plot.UKESM_PRECIP_CONST
        #         for key in ['bins', 'mean', 'p95', 'p99', 'p999', 'p5']:
        #             data[key] *= plot.UKESM_PRECIP_CONST

        # if variable == 'geopotential_500':
        #     for data in [truth_dist, forecast_dist]:
        #         data['hist']  /= plot.UKESM_GEOPOT_CONST
        #         for key in ['bins', 'mean', 'p95', 'p99', 'p999', 'p5']:
        #             data[key] *= plot.UKESM_GEOPOT_CONST

        if past:
            truth_dist['label'] = 'U_T1'
            truth_dist['label_full'] = 'Test UKESM 2011-2014 (U_T1)'
            forecast_dist['label'] = ''
            forecast_dist['label_full'] = f'UKESM {model_short_name} 2011-2014'
        else:
            truth_dist['label'] = 'U_T2'
            truth_dist['label_full'] = 'Test UKESM 2097-2100 (U_T2)'
            forecast_dist['label'] = ''
            forecast_dist['label_full'] = f'UKESM {model_short_name} 2097-2100'
        if (variable == 'total_precipitation_6hr') and i ==0:
                precip_p99=truth_dist['p99']
        dist.plot_distributions_with_nans_on_axis(ax,
                                                [truth_dist, forecast_dist],
                                                background=[train_dist_UKESM],
                                                bin_num=1000 if (variable == 'total_precipitation_6hr') else 500,
                                                variable_name=display_name,
                                                unit=unit,
                                                title=f"{'U_T1' if past else 'U_T2'}: {display_name} ({model_short_name}, {hours_into_future}h)",
                                                plot_legend=True,
                                                plot_5_quantile=plot_5_quant,plot_99_quant=(variable == 'total_precipitation_6hr'))

    
for model_idx in range(3):
    display_name, unit, variable, plevel, _ = plot.KEY_VARIABLES_UKESM[var_index]
    # collect all limits in this row
    xmins, xmaxs = [], []
    ymins, ymaxs = [], []
    for i, hours_into_future in enumerate([True, False]):
        
        ax = axes[model_idx, i]
        xmin, xmax = ax.get_xlim()
        ymin, ymax = ax.get_ylim()
        print(f'{var_index}, {i}, {ax.get_ylim()}')
        xmins.append(xmin)
        xmaxs.append(xmax)
        ymins.append(ymin)
        ymaxs.append(ymax)
    # set same limits for all in row i
    row_xlim = dist.get_xlim(display_name, dataset='both')
    row_ylim = (min(ymins), max(ymaxs))
    for i, hours_into_future in enumerate([True, False]):
        axes[model_idx, i].set_xlim(row_xlim)
        if variable == 'total_precipitation_6hr':
            axes[model_idx, i].set_yscale('log')
        else:
            axes[model_idx, i].set_ylim(row_ylim)
        # axes[var_index, i].set_ylim(row_ylim)
        # if variable == 'total_precipitation_6hr':
        #     axes[var_index, i].set_xlabel(f"{display_name} [{unit}], cut off at GT 99% ({precip_p99:.2f}{unit})" if unit else f"{display_name}, cut of at GT 99% ({precip_p99:.2f})")
plt.tight_layout()
plt.savefig(save_to+save_name, bbox_inches="tight", dpi=600)
# plt.show()
# Out:
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_dist_shift_geopotential_multiple_models_past_future_24_120_240.pdf
# Evaluating model: UKESM z64 Multi-Mesh
# z64_past
# Processing var Geopotential at 500hPa (1/8)
# loading U_TR/GT_geopotential_500.npz
#     Calculating distribution 1 of 2
# loading U_T1/GT_geopotential_500_120.npz
# loading U_T1/FC_geopotential_500_120_z64_past.npz
#     Calculating distribution 2 of 2
# loading U_T2/GT_geopotential_500_120.npz
# loading U_T2/FC_geopotential_500_120_z64_future.npz
# Evaluating model: UKESM z256 Multi-Mesh
# z256_past
# Processing var Geopotential at 500hPa (1/8)
# loading U_TR/GT_geopotential_500.npz
#     Calculating distribution 1 of 2
# loading U_T1/GT_geopotential_500_120.npz
# loading U_T1/FC_geopotential_500_120_z256_past.npz
#     Calculating distribution 2 of 2
# loading U_T2/GT_geopotential_500_120.npz
# loading U_T2/FC_geopotential_500_120_z256_future.npz
# Evaluating model: UKESM z64 Hierarchical
# z64 hierarchical_past
# Processing var Geopotential at 500hPa (1/8)
# loading U_TR/GT_geopotential_500.npz
#     Calculating distribution 1 of 2
# loading U_T1/GT_geopotential_500_120.npz
# loading U_T1/FC_geopotential_500_120_z64 hierarchical_past.npz
#     Calculating distribution 2 of 2
# loading U_T2/GT_geopotential_500_120.npz
# loading U_T2/FC_geopotential_500_120_z64 hierarchical_future.npz
# 0, 0, (0.0, 0.0010650898102889774)
# 0, 1, (0.0, 0.0009358299499321229)
# 0, 0, (0.0, 0.000983910089960513)
# 0, 1, (0.0, 0.0010869466063099075)
# 0, 0, (0.0, 0.000979000231074429)
# 0, 1, (0.0, 0.0009358299499321229)

# %% [markdown]
# # Plot Non-Interpolated - Interpolated next to each other

# %%
compute = False

model_short_names = ['z64-MM','z256-MM']
model_short_names_interpolated = ['z64-MM-I','z256-MM-I']
model_idx=0

save_to='/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/'
save_name='UKESM_dist_shift_temperature_multiple_models_future_with_interpolated_24_120_240.pdf'
print(save_to+save_name)
steps=5*24
# steps=[6, 48]#, 5*24, 10*24]
num_vars = len(plot.KEY_VARIABLES_UKESM)
precip_p99=0
nrows=2
ncols=2
past=False

future_models = [plot.FUTURE_MODELS_UKESM[0], plot.FUTURE_MODELS_UKESM[2]]
future_models_interpolated = [plot.FUTURE_MODELS_UKESM_HOLES_FILLED[0], plot.FUTURE_MODELS_UKESM_HOLES_FILLED[1]]

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(6*ncols,3*nrows), sharex=False, sharey=False)
create_folder_if_not_exists(save_to)

for model_idx in range(2):
    j = model_idx
    
    selected_model_future=future_models[model_idx]
    selected_model_future_interpolated=future_models_interpolated[model_idx]
    print(f'Evaluating model: {selected_model_future["model_name"]}')
    
    base_save_folder_future = selected_model_future['plot_folder']
    compute = False
    
    # for var_index in range(6,7):
    var_index=1
    display_name, unit, variable, plevel,_ = plot.KEY_VARIABLES_UKESM[var_index]
    plot_5_quant = variable in ['u_component_of_wind','v_component_of_wind','relative_vorticity']
    print(f'Processing var {display_name} ({var_index+1}/{num_vars})')
    train_dist_UKESM = dist.load_dist(variable, dataset='U',dataslice_name='TR', is_ground_truth=True)
    train_dist_UKESM['label'] = 'U_TR'
    train_dist_UKESM['label_full'] = 'Train UKESM 1985-2010 (U_TR)'
            
    for i, interpolated in enumerate([False,True]):
        print(f'    Calculating distribution {i+1} of {2}')
        hours_into_future = steps
        ax = axes[j, i]
        selected_model = selected_model_future_interpolated if interpolated else selected_model_future
        model_short_name = model_short_names_interpolated[model_idx] if interpolated else model_short_names[model_idx]
        
        truth_dist = dist.load_dist(variable, dataset='U',dataslice_name='T2', is_ground_truth=True, rollout=hours_into_future)
        forecast_dist = dist.load_dist(variable, dataset='U',dataslice_name='T2', is_ground_truth=False, rollout=hours_into_future, model_id=selected_model['id'])
        

        
        truth_dist['label'] = 'U_T2'
        truth_dist['label_full'] = 'Test UKESM 2097-2100 (U_T2)'
        train_dist_UKESM['label'] = 'U_TR'
        train_dist_UKESM['label_full'] = 'Train UKESM 1985-2010 (U_TR)'
        if interpolated:
            truth_dist['label'] = 'UI_T2'
            truth_dist['label_full'] = 'Test UKESM 2097-2100 (UI_T2)'
            train_dist_UKESM['label'] = 'UI_TR'
            train_dist_UKESM['label_full'] = 'Train UKESM 1985-2010 (UI_TR)'
        forecast_dist['label'] = ''
        forecast_dist['label_full'] = f'UKESM {model_short_name} 2097-2100'
        
        dist.plot_distributions_with_nans_on_axis(ax,
                                                [truth_dist, forecast_dist],
                                                background=[train_dist_UKESM],
                                                bin_num=1000 if (variable == 'total_precipitation_6hr') else 500,
                                                variable_name=display_name,
                                                unit=unit,
                                                title=f"{'UI_T2' if interpolated else 'U_T2'}: {display_name} ({model_short_name}, {hours_into_future}h)",
                                                plot_legend=True,
                                                plot_5_quantile=plot_5_quant,plot_99_quant=(variable == 'total_precipitation_6hr'))

    
for model_idx in range(2):
    display_name, unit, variable, plevel, _ = plot.KEY_VARIABLES_UKESM[var_index]
    # collect all limits in this row
    xmins, xmaxs = [], []
    ymins, ymaxs = [], []
    for i, hours_into_future in enumerate([True, False]):
        
        ax = axes[model_idx, i]
        xmin, xmax = ax.get_xlim()
        ymin, ymax = ax.get_ylim()
        print(f'{var_index}, {i}, {ax.get_ylim()}')
        xmins.append(xmin)
        xmaxs.append(xmax)
        ymins.append(ymin)
        ymaxs.append(ymax)
    # set same limits for all in row i
    row_xlim = dist.get_xlim(display_name, dataset='both')
    row_ylim = (min(ymins), max(ymaxs))
    for i, hours_into_future in enumerate([True, False]):
        axes[model_idx, i].set_xlim(row_xlim)
        if variable == 'total_precipitation_6hr':
            axes[model_idx, i].set_yscale('log')
        else:
            axes[model_idx, i].set_ylim(row_ylim)
        # axes[var_index, i].set_ylim(row_ylim)
        # if variable == 'total_precipitation_6hr':
        #     axes[var_index, i].set_xlabel(f"{display_name} [{unit}], cut off at GT 99% ({precip_p99:.2f}{unit})" if unit else f"{display_name}, cut of at GT 99% ({precip_p99:.2f})")
plt.tight_layout()
plt.savefig(save_to+save_name, bbox_inches="tight", dpi=600)
# plt.show()
# Out:
# /home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/plots/distribution_shift_error/UKESM_dist_shift_temperature_multiple_models_future_with_interpolated_24_120_240.pdf
# Evaluating model: UKESM z64 Multi-Mesh
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 2
# loading U_T2/GT_temperature_120.npz
# loading U_T2/FC_temperature_120_z64_future.npz
#     Calculating distribution 2 of 2
# loading U_T2/GT_temperature_120.npz
# loading U_T2/FC_temperature_120_z64_future_interpolated.npz
# Evaluating model: UKESM z256 Multi-Mesh
# Processing var Temperature at 850hPa (2/8)
# loading U_TR/GT_temperature.npz
#     Calculating distribution 1 of 2
# loading U_T2/GT_temperature_120.npz
# loading U_T2/FC_temperature_120_z256_future.npz
#     Calculating distribution 2 of 2
# loading U_T2/GT_temperature_120.npz
# loading U_T2/FC_temperature_120_z256_future_interpolated.npz
# 1, 0, (0.0, 0.09736291360048402)
# 1, 1, (0.0, 0.09736291360048402)
# 1, 0, (0.0, 0.09880747055990066)
# 1, 1, (0.0, 0.11100663447141282)

# %%
plt.show()

# %%
fig.savefig(save_to+save_name, bbox_inches="tight", dpi=600)

# %%
# def get_temporal_index_in_dataset(timestamp, ds):
#     """
#     Returns the integer index of a given timestamp in an xarray Dataset
#     that may use non-Gregorian calendars (e.g., 360_day).
    
#     timestamp: cftime.Datetime object or a string parseable by cftime
#     ds: xarray.Dataset or DataArray with a 'time' coordinate
#     """
#     import cftime

#     # Iterate over time coordinates to find match
#     for i, t in enumerate(ds.time.values):
#         if t == timestamp:
#             return i
    
#     # If not found, raise error
#     raise ValueError(f"Timestamp {timestamp} not found in dataset time axis.")

    
# def get_true_data_matching_forecast_timestamps(ds_truth, ds_forecast, prediction_steps):
#     '''
#     prediction_steps should be 0 based -> 0 means using the first prediction of the model for that timestamp
#     '''
#     first_timestamp_forecast = ds_forecast.time[0].values
#     last_timestamp_forecast = ds_forecast.time[-1].values
#     idx_truth_first = get_temporal_index_in_dataset(first_timestamp_forecast, ds_truth) + prediction_steps+1
#     idx_truth_last = get_temporal_index_in_dataset(last_timestamp_forecast, ds_truth) + prediction_steps+1
#     new_forecast = ds_forecast.copy().isel(prediction_timedelta=prediction_steps)
#     new_truth = ds_truth.isel(time=slice(idx_truth_first, idx_truth_last + 1)).isel(time=slice(0, None, 2))
#     new_forecast = new_forecast.sortby('time')
#     _, index = np.unique(new_forecast['time'], return_index=True)
#     new_forecast = new_forecast.isel(time=np.sort(index))
    
#     for t in range(len(new_forecast.time.values)-1):
#         if not str(new_forecast.time.values[t+1] - new_forecast.time.values[t]) == '12:00:00':
#             print(f'Error with {new_forecast.time.values[t]} and {new_forecast.time.values[t+1]}')
#     new_forecast = new_forecast.assign_coords({'time': new_truth['time']})
#     return new_truth, new_forecast
# def weighted_quantile(values, quantile, sample_weight=None):
#     """Compute weighted quantile (0–1)."""
#     sorter = np.argsort(values)
#     values, weights = values[sorter], sample_weight[sorter]
#     cdf = np.cumsum(weights) / np.sum(weights)
#     return np.interp(quantile, cdf, values)

# def format_shift(value, unit=""):
#     """Dynamically format small shift values with appropriate precision."""
#     abs_val = abs(value)
#     if abs_val >= 0.1:
#         fmt = f"{value:+.2f}"   # ±0.12
#     elif abs_val >= 0.01:
#         fmt = f"{value:+.3f}"   # ±0.012
#     elif abs_val >= 0.001:
#         fmt = f"{value:+.4f}"   # ±0.0012
#     else:
#         fmt = f"{value:+.1e}"   # scientific notation for really tiny shifts
#     return f"{fmt}{unit}"
# def format_value(value, unit=""):
#     """Dynamically format small shift values with appropriate precision."""
#     abs_val = abs(value)
#     if abs_val >= 0.1:
#         fmt = f"{value:.2f}"   # ±0.12
#     elif abs_val >= 0.01:
#         fmt = f"{value:.3f}"   # ±0.012
#     elif abs_val >= 0.001:
#         fmt = f"{value:.4f}"   # ±0.0012
#     else:
#         fmt = f"{value:.1e}"   # scientific notation for really tiny shifts
#     return f"{fmt}{unit}"

# def calc_single_dist_with_nans(obs_1,lat_name="latitude", log_x=False):

#     # --- Compute cosine(lat) weights ---
#     lats_1 = obs_1[lat_name].values
#     w_lat_1 = np.cos(np.deg2rad(lats_1))
#     w_1 = np.broadcast_to(w_lat_1[None, None, :], obs_1.shape)  # shape (time, lat, lon)

#     # --- Flatten values and weights ---
#     vals1 = obs_1.values.flatten()
    
#     w1 = w_1.flatten()

#     # --- Remove NaNs safely ---
#     mask1 = np.isfinite(vals1)
#     vals1 = vals1[mask1]
#     w1 = w1[mask1]
#     # --- Weighted means ---
#     mean1 = np.average(vals1, weights=w1)
#     # --- Weighted 95th percentiles ---
#     p95_1 = weighted_quantile(vals1, 0.95, sample_weight=w1)
#     p99_1 = weighted_quantile(vals1, 0.99, sample_weight=w1)
#     p99_9_1 = weighted_quantile(vals1, 0.999, sample_weight=w1)
#     p5_1 = weighted_quantile(vals1, 0.05, sample_weight=w1)

#     if log_x:
#         vals1 = vals1 + 1e-6

#     return {'vals': vals1, 'weights':w1 / w1.sum(), 'mean':mean1, 'p95':p95_1, 'p99':p99_1, 'p999':p99_9_1, 'p5':p5_1}

# def plot_distributions_with_nans_on_axis(
#     ax,
#     obs,
#     background,
#     bin_num=50,
#     variable_name="Variable",
#     unit='',
#     title='',
#     plot_legend=True,
#     colors=None,
#     plot_5_quantile=False,
#     log_x=False,
#     log_y =False,
#     plot_99_quant=False
# ):
#     """
#     Plot weighted histograms of distributions for obs_2019 vs obs_2049.
#     Handles NaNs safely after masking.

#     Parameters
#     ----------
#     obs : xarray.DataArray
#         Input data with dims (time, lat, lon)
#     lat_name : str
#         Name of the latitude coordinate
#     bins : int
#         Number of bins for the histogram
#     variable_name : str
#         Label for x-axis
#     unit : str
#         Unit string for labels
#     save_to : str or None
#         File path to save the figure (if None, show interactively)
#     """
#     if not colors:
#         colors = [f'C{i}' for i in range(len(obs))]
#     for i in range(len(obs)):
#         obs[i]['color'] = colors[i]
        
#     mean = []
#     p95 = []
#     # --- Add vertical lines ---
#     bins=bin_num

#     def draw_lines(data, reference=None, print_difference=False,plot_5_quantile=False,plot_legend=True):
#         if (not print_difference):
#             mean_l = f"{data['label']} mean ({format_value(data['mean'], unit)})" if plot_legend else None
#             if plot_99_quant:
#                 p95_l = f"{data['label']} 99.9th % ({format_value(data['p999'], unit)})" if plot_legend else None
#             else:
#                 p95_l = f"{data['label']} 95th % ({format_value(data['p95'], unit)})" if plot_legend else None
#             p5_l = f"{data['label']} 5th % ({format_value(data['p5'], unit)})" if plot_legend else None
#         else:
#             mean_l = f"{data['label']} mean ({reference['label']}{format_shift(obs[i]['mean'] - obs[0]['mean'], unit)})" if plot_legend else f"{reference['label']}{format_shift(obs[i]['mean'] - obs[0]['mean'], unit)}"
#             if plot_99_quant:
#                 p95_l = f"{data['label']} 99.9th % ({reference['label']}{format_shift(obs[i]['p999'] - obs[0]['p999'], unit)})" if plot_legend else f"{reference['label']}{format_shift(obs[i]['p999'] - obs[0]['p999'], unit)}"
#             else:
#                 p95_l = f"{data['label']} 95th % ({reference['label']}{format_shift(obs[i]['p95'] - obs[0]['p95'], unit)})" if plot_legend else f"{reference['label']}{format_shift(obs[i]['p95'] - obs[0]['p95'], unit)}"
#             p5_l = f"{data['label']} 5th % ({reference['label']}{format_shift(obs[i]['p5'] - obs[0]['p5'], unit)})" if plot_legend else f"{reference['label']}{format_shift(obs[i]['p5'] - obs[0]['p5'], unit)}"
#         ax.axvline(data['mean'], color=data['color'], linestyle=(0, (1, 0)), linewidth=2, label=mean_l)
#         ax.axvline(data['p999'] if plot_99_quant else data['p95'], color=data['color'], linestyle=(0, (1, 3)), linewidth=2, label=p95_l)
#         if plot_5_quantile:
#             ax.axvline(data['p5'], color=data['color'], linestyle=(0, (5, 3)), linewidth=2, label=p5_l)
    
#     # if plot_legend:
#     for i in range(len(background)):
#         if 'hist' in background[i].keys():
#             ax.hist(background[i]['bins'][:-1], background[i]['bins'], weights=background[i]['hist'], alpha=0.5,label=background[i]['label_full'] if plot_legend else None,color='grey',)
#         else:
#             ax.hist(background[i]['vals'],bins=bins,weights=background[i]['weights'],alpha=0.5,label=background[i]['label_full'] if plot_legend else None,density=True,color='grey',)
#     for i in range(len(obs)):
#         if log_x:
#             bins = np.logspace(np.log10(1e-6), np.log10(obs[i]['vals'].max()), bin_num)
#         if 'hist' in obs[i].keys():
#             ax.hist(obs[i]['bins'][:-1], obs[i]['bins'], weights=obs[i]['hist'], alpha=0.5,label=obs[i]['label_full'] if plot_legend else None,color=obs[i]['color'])
#         else:
#             ax.hist(obs[i]['vals'],bins=bins,weights=obs[i]['weights'],alpha=0.5,label=obs[i]['label_full'] if plot_legend else None,density=True,color=obs[i]['color'])
#         draw_lines(obs[i], reference=obs[0], print_difference=not(i==0), plot_5_quantile=plot_5_quantile,plot_legend=plot_legend)
            

#     # --- Labels and layout ---
#     ax.set_xlabel(f"{variable_name} [{unit}]" if unit else variable_name)
#     if not log_x:
#         ax.ticklabel_format(style="sci", axis="x", scilimits=(-3, 3))
#     #ax.locator_params(axis='x', nbins=5)
#     ax.xaxis.get_offset_text().set_fontsize(8)
#     if plot_legend:
#         ax.set_ylabel("Probability density")
#     if log_x:
#         ax.set_xscale('log')
#     # ax.set_yscale('log')
#     ax.set_title(title)
#     ax.legend()
#     ax.grid(True, alpha=0.3)
        
# def plot_distributions_with_nans(
#     obs,
#     lat_name="latitude",
#     bins=50,
#     variable_name="Variable",
#     unit='',
#     save_to=None,
#     title='',
#     labels=[],
#     colors=None,
#     plot_5_quantile=False,
#     display_name=''
# ):
#     """
#     Plot weighted histograms of distributions for obs_2019 vs obs_2049.
#     Handles NaNs safely after masking.

#     Parameters
#     ----------
#     obs_1, obs_2 : xarray.DataArray
#         Input data with dims (time, lat, lon)
#     lat_name : str
#         Name of the latitude coordinate
#     bins : int
#         Number of bins for the histogram
#     variable_name : str
#         Label for x-axis
#     unit : str
#         Unit string for labels
#     save_to : str or None
#         File path to save the figure (if None, show interactively)
#     """
#     if 'precip' in variable_name.lower():
#         fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(7,6))
#         plot_distributions_with_nans_on_axis(ax=axes,
#                                              obs=obs,
#                                              background=[],
#                                              bin_num=bins,
#                                              variable_name=variable_name,
#                                              unit=unit,
#                                              colors=colors,
#                                              title=title,
#                                             plot_5_quantile=plot_5_quantile,plot_99_quant=True)
#         axes.set_yscale('log')
#         if save_to:
#             plt.savefig(save_to.replace('.png','_y_log.png'), bbox_inches="tight", dpi=300)
#         else:
#             plt.show()
#         bins=1200
            
#     fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(7,6))
#     plot_distributions_with_nans_on_axis(ax=axes,
#                                          obs=obs,
#                                          background=[],
#                                          bin_num=bins,
#                                          variable_name=variable_name,
#                                          unit=unit,
#                                          colors=colors,
#                                          title=title,
#                                         plot_5_quantile=plot_5_quantile)
#     if 'u-component' in variable_name.lower() or 'v-component' in variable_name.lower():
#         axes.set_xlim((-100, 40))
#     if 'vorticity' in variable_name.lower():
#         axes.set_xlim((-4e-4, 2e-4))
#     if 'precip' in variable_name.lower():
#         xmin, xmax = axes.get_xlim()
#         row_xlim = (xmin, obs[0]['p99'])
#         axes.set_xlim(row_xlim)
#         axes.set_xlabel(f"{display_name} [{unit}], cut off at {obs[0]['label']} 99% ({obs[0]['p99']:.2f}{unit})" if unit else f"{display_name}, cut of at GT 99% ({obs[0]['p99']:.2f})")
    

#     if save_to:
#         plt.savefig(save_to, bbox_inches="tight", dpi=300)
#     else:
#         plt.show()
 
# def get_datasets_after(ds_true, ds_forecast, hours_into_future=None, days_into_future=None):
#     steps=-1
#     if days_into_future:
#         steps+=4*days_into_future
#     if hours_into_future:
#         if not hours_into_future%6 == 0:
#             print(f'    Warning, given hours: {hours_into_future} cannot be divided by step length (6)')
#         steps+=int(hours_into_future/6)
#     if steps == -1:
#         steps=0
#         print(f'    No valid length provided, setting steps={steps} (=={(steps+1)*6} hours)')
#     else:
#         print(f'    Starting with a step length of {steps} (=={(steps+1)*6} hours)')
#     return (get_true_data_matching_forecast_timestamps(ds_true, ds_forecast, steps))
# def precompute_and_save_distribution(data, save_name, save_folder, bins=500):
#     hist, edges = np.histogram(data['vals'], bins=bins, weights=data['weights'], density=True)
#     data['hist'] = hist
#     data['bins'] = edges

#     data_new = {}
#     for key in data.keys():
#         if key=='vals' or key=='weights':
#             continue
#         data_new[key] = data[key]
        

#     np.savez(save_folder + '/' + save_name + ".npz", **data_new)

# %%
computed = truth.where(mask_sel).compute()
min_coords = computed.where(computed == 0, drop=True)
print(truth)
print(min_coords.time)
# Out:
# <xarray.DataArray 'total_precipitation_6hr' (time: 2860, longitude: 128,
#                                              latitude: 64)> Size: 94MB
# dask.array<getitem, shape=(2860, 128, 64), dtype=float32, chunksize=(20, 128, 64), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude   (latitude) float64 512B -90.0 -87.14 -84.29 ... 84.29 87.14 90.0
#   * longitude  (longitude) float64 1kB 0.0 2.812 5.625 ... 351.6 354.4 357.2
#   * time       (time) object 23kB 2097-01-11 06:00:00 ... 2100-12-30 18:00:00
# Attributes:
#     description:  Computed from 3-hourly precipitation rate (kg m-2 s-1) usin...
#     long_name:    Total precipitation accumulated over 6 hours
#     units:        kg m-2
# <xarray.DataArray 'time' (time: 2860)> Size: 23kB
# array([cftime.Datetime360Day(2097, 1, 11, 6, 0, 0, 0, has_year_zero=True),
#        cftime.Datetime360Day(2097, 1, 11, 18, 0, 0, 0, has_year_zero=True),
#        cftime.Datetime360Day(2097, 1, 12, 6, 0, 0, 0, has_year_zero=True), ...,
#        cftime.Datetime360Day(2100, 12, 29, 18, 0, 0, 0, has_year_zero=True),
#        cftime.Datetime360Day(2100, 12, 30, 6, 0, 0, 0, has_year_zero=True),
#        cftime.Datetime360Day(2100, 12, 30, 18, 0, 0, 0, has_year_zero=True)],
#       dtype=object)
# Coordinates:
#   * time     (time) object 23kB 2097-01-11 06:00:00 ... 2100-12-30 18:00:00
# Attributes:
#     long_name:    t
#     time_origin:  01-JAN-2015:00:00:00

# %%
for t in min_coords.time:
    plot.plot_single_plot(truth.sel(time=t).where(mask_sel).T, f'temp forecast at {plevel}', 'temperature', None, 'viridis', "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/", 'test_experiment', show=True)

# %%
plot.plot_single_plot(ukesm_historical_truth_equiangular_wp_cons.isel(time=-1).sel(level=plevel)[variable].T, f'temp forecast at {plevel}', 'temperature', None, 'viridis', "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/", 'test_experiment', show=True)

# %%
print(ukesm_historical_truth_equiangular_wp_cons.sel(level=plevel)[variable])
# Out:
# <xarray.DataArray 'temperature' (time: 43199, longitude: 128, latitude: 64)> Size: 1GB
# dask.array<getitem, shape=(43199, 128, 64), dtype=float32, chunksize=(40, 128, 64), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude   (latitude) float64 512B -90.0 -87.14 -84.29 ... 84.29 87.14 90.0
#     level      float32 4B 850.0
#   * longitude  (longitude) float64 1kB 0.0 2.812 5.625 ... 351.6 354.4 357.2
#   * time       (time) object 346kB 1985-01-01 06:00:00 ... 2014-12-30 18:00:00
# Attributes:
#     date:           01/01/50
#     long_name:      Temperature T
#     name:           temp
#     source:         Unified Model Output (Vn10.9):
#     standard_name:  air_temperature
#     time:           00:00
#     title:          Temperature T
#     units:          K
#     valid_max:      312.37158203125
#     valid_min:      0.0

# %%
# Out:
# [200. 300. 500. 700. 850. 925.]

# %%
plevel = 700
mask_threshold=plot.MASK_VALUES_UKESM_TEMPERATURE[str(plevel)]
truth = ds_test_truth.sel(level=plevel)[variable].isel(time=12*60)
forecast=ds_test_forecast.sel(level=plevel)[variable].isel(time=12*60)
plot.plot_single_plot(truth.where(truth >= mask_threshold).T, f'temp at {plevel}', 'temperature', (mask_threshold,350), 'viridis', "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/", 'test')
plot.plot_single_plot(forecast.where(truth >= mask_threshold).T, f'temp forecast at {plevel}', 'temperature', (mask_threshold,350), 'viridis', "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/", 'test_forecast')

# %%
print(ds_test_truth.level.values)
plevel = 850
# Out:
# [200. 300. 500. 700. 850. 925.]

# %%
lowest_temp = ukesm_future_truth_equiangular_wp_cons.sel(level=plevel)[variable].min(dim='time')
print(lowest_temp)
plot.plot_single_plot(lowest_temp.T, f'Lowest temperature per coordinate at {plevel}hPa', 'temperature', None, 'viridis', "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/", 'lowest_temp_val_850')
# Out:
# <xarray.DataArray 'temperature' (longitude: 128, latitude: 64)> Size: 33kB
# dask.array<_nanmin_skip-aggregate, shape=(128, 64), dtype=float32, chunksize=(128, 64), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude   (latitude) float64 512B -90.0 -87.14 -84.29 ... 84.29 87.14 90.0
#     level      float32 4B 850.0
#   * longitude  (longitude) float64 1kB 0.0 2.812 5.625 ... 351.6 354.4 357.2

# %%
from tqdm import tqdm
experiment = lowest_temp.where(lowest_temp >= mask_threshold).copy()
print(experiment.values.shape)
vals = experiment.values

plot.plot_single_plot(experiment.T, f'Lowest temperature per coordinate at {plevel}hPa (Impossible masked out)', 'temperature', (mask_threshold,350), 'viridis', "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/", 'lowest_temp_val_850_impossible_masked')
# Out:
# (128, 64)

# %%
shifted_1 = experiment.isel(longitude=slice(0,-1))
shifted_2 = experiment.isel(longitude=slice(1,None))
shifted_2['longitude'] = shifted_1.longitude
diff=(shifted_1-shifted_2)
# pad diff to match experiment dims
pad_lat = experiment.latitude.size - diff.latitude.size
pad_lon = experiment.longitude.size - diff.longitude.size
# plot.plot_single_plot(diff.T, f'temp forecast at {plevel}', 'temperature', None, 'viridis', "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/", 'test_experiment', show=True)

diff_padded = xr.concat(
    [xr.full_like(diff.isel(latitude=slice(-pad_lat, None), longitude=slice(-pad_lon, None)), -70), diff],
    dim='longitude'
)


diff_padded_left = diff_padded.fillna(0)
diff_padded_left['longitude'] = truth.longitude
# plot.plot_single_plot(experiment.T, f'temp forecast at {plevel}', 'temperature', None, 'viridis', "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/", 'test_experiment', show=True)
# plot.plot_single_plot(experiment.where(diff_padded_left<20).T, f'temp forecast at {plevel}', 'temperature', None, 'viridis', "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/", 'test_experiment', show=True)

# %%
shifted_1 = experiment.isel(longitude=slice(0,-1))
shifted_2 = experiment.isel(longitude=slice(1,None))
shifted_1['longitude'] = shifted_2.longitude
diff=(shifted_2-shifted_1)
# pad diff to match experiment dims
pad_lat = experiment.latitude.size - diff.latitude.size
pad_lon = experiment.longitude.size - diff.longitude.size

diff_padded = xr.concat(
    [diff, xr.full_like(diff.isel(latitude=slice(-pad_lat, None), longitude=slice(-pad_lon, None)), -70)],
    dim='longitude'
)


diff_padded_right = diff_padded.fillna(0)
diff_padded_right['longitude'] = truth.longitude

# %%
# Shift experiment data up and down along latitude
shifted_up = experiment.isel(latitude=slice(0, -1))   # all except last latitude
shifted_down = experiment.isel(latitude=slice(1, None))  # all except first latitude
shifted_down['latitude'] = shifted_up.latitude  # align coordinates

# Compute difference between neighboring latitude bands
diff_lat = shifted_up - shifted_down

# Pad diff_lat to match experiment dimensions
pad_lat = experiment.latitude.size - diff_lat.latitude.size
pad_lon = experiment.longitude.size - diff_lat.longitude.size



# Pad along latitude to restore full grid
diff_lat_padded = xr.concat(
    [xr.full_like(diff_lat.isel(latitude=slice(-pad_lat, None)), -70), diff_lat],
    dim='latitude'
)

# Replace NaNs and realign coordinates
diff_padded_down = diff_lat_padded.fillna(0)
diff_padded_down['latitude'] = truth.latitude

# %%
# Shift experiment data up and down along latitude
shifted_up = experiment.isel(latitude=slice(0, -1))   # all except last latitude
shifted_down = experiment.isel(latitude=slice(1, None))  # all except first latitude
shifted_up['latitude'] = shifted_down.latitude  # align coordinates

# Compute difference between neighboring latitude bands
diff_lat = shifted_down - shifted_up

# Pad diff_lat to match experiment dimensions
pad_lat = experiment.latitude.size - diff_lat.latitude.size
pad_lon = experiment.longitude.size - diff_lat.longitude.size



# Pad along latitude to restore full grid
diff_lat_padded = xr.concat(
    [diff_lat,xr.full_like(diff_lat.isel(latitude=slice(-pad_lat, None)), -70)],
    dim='latitude'
)

# Replace NaNs and realign coordinates
diff_padded_up = diff_lat_padded.fillna(0)
diff_padded_up['latitude'] = truth.latitude

# Plot the difference field (optional diagnostic)
plot.plot_single_plot(
    diff_padded_up.T,
    f'temp forecast lat-diff at {plevel}',
    'temperature',
    None,
    'viridis',
    "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/",
    'test_experiment_latdiff',
    show=True
)

# Plot original and filtered results
plot.plot_single_plot(
    experiment.T,
    f'temp forecast at {plevel}',
    'temperature',
    None,
    'viridis',
    "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/",
    'test_experiment_lat',
    show=True
)
thresh=15
temp_mask = experiment.where(diff_padded_up < thresh).where(diff_padded_down < thresh).where(diff_padded_left < thresh).where(diff_padded_right < thresh)
plot.plot_single_plot(
    temp_mask.T,
    f'temp forecast at {plevel}',
    'temperature',
    None,
    'viridis',
    "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/",
    'test_experiment_lat_filtered',
    show=True
)
thresh=10
temp_mask = experiment.where(diff_padded_up < thresh).where(diff_padded_down < thresh).where(diff_padded_left < thresh).where(diff_padded_right < thresh)
plot.plot_single_plot(
    temp_mask.T,
    f'Lowest temperature per coordinate at {plevel}hPa (Impossible masked out and filtered)',
    'temperature',
    None,
    'viridis',
    "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/",
    'lowest_temp_val_850_impossible_masked_and_filtered_thresh_10'
)

# %%
ds = xr.open_dataset("valid_mask.zarr")
mask2 = ds[f'temperature_{plevel}']

# %%
mask = xr.where(temp_mask.notnull(), 1, 0)  # 1 = valid, 0 = invalid
# combined_mask = mask * mask2
# plot.plot_single_plot(
#     combined_mask.T,
#     f'temp forecast at {plevel}',
#     'temperature',
#     None,
#     'viridis',
#     "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/",
#     'test_experiment_lat_filtered',
#     show=True
# )
combined_mask = mask 
combined_mask = combined_mask.drop_vars(["level"])

combined_mask = combined_mask.chunk(longitude=-1, latitude=-1)
print(combined_mask)
combined_mask.to_dataset(name=f"temperature_{plevel}").to_zarr(f"combined_valid_mask.zarr_future", mode='a')
# Out:
# <xarray.DataArray 'temperature' (longitude: 128, latitude: 64)> Size: 66kB
# dask.array<rechunk-merge, shape=(128, 64), dtype=int64, chunksize=(128, 64), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude   (latitude) float64 512B -90.0 -87.14 -84.29 ... 84.29 87.14 90.0
#   * longitude  (longitude) float64 1kB 0.0 2.812 5.625 ... 351.6 354.4 357.2
#     time       object 8B 2098-01-11 06:00:00

# %%
print(plevel)
# Out:
# 850

# %%
ds = xr.open_dataset("combined_valid_mask.zarr")
print(ds)
# Out:
# <xarray.Dataset> Size: 198kB
# Dimensions:          (latitude: 64, longitude: 128)
# Coordinates:
#   * latitude         (latitude) float64 512B -90.0 -87.14 -84.29 ... 87.14 90.0
#   * longitude        (longitude) float64 1kB 0.0 2.812 5.625 ... 354.4 357.2
# Data variables:
#     temperature_700  (longitude, latitude) int64 66kB ...
#     temperature_850  (longitude, latitude) int64 66kB ...
#     temperature_925  (longitude, latitude) int64 66kB ...

# %%
make_nan = []
for ilon in tqdm(range(experiment.values.shape[0]-1)):
    for ilat in range(experiment.values.shape[1]-1):
        p1 = experiment.values[ilon][ilat]
        p2 = experiment.values[ilon][ilat+1]
        p3 = experiment.values[ilon+1][ilat]
        if not p1==np.nan and not p2==np.nan:
            if p1-p2 > 20:
                make_nan.append((ilon,ilat+1))
            elif p2-p1 > 20:
                make_nan.append((ilon,ilat))
        if not p1==np.nan and not p3==np.nan:
            if p1-p3 > 20:
                make_nan.append((ilon+1,ilat))
            elif p3-p1 > 20:
                make_nan.append((ilon,ilat))
# Out:
# 100%|██████████| 127/127 [04:02<00:00,  1.91s/it]

# %%
make_nan=true_make_nan

# %%
for p in true_make_nan:
    print(p)
    experiment.isel(latitude=p[1], longitude=p[0]).values[...] = np.nan
plot.plot_single_plot(experiment.T, f'temp at {plevel}', 'temperature', (mask_threshold,350), 'viridis', "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/", 'experiment')
# Out:
# (13, 36)
# (13, 36)
# (14, 45)
# (14, 36)
# (14, 36)
# (14, 45)
# (16, 44)
# (17, 8)
# (16, 44)
# (17, 43)
# (16, 46)
# (16, 46)
# (17, 8)
# (17, 43)
# (18, 42)
# (17, 45)
# (17, 45)
# (18, 42)
# (20, 43)
# (20, 43)
# (21, 8)
# (22, 43)
# (22, 44)
# (22, 8)
# (22, 43)
# (22, 44)
# (24, 42)
# (24, 45)
# (24, 7)
# (24, 7)
# (24, 42)
# (24, 42)
# (24, 45)
# (26, 47)
# (26, 43)
# (27, 42)
# (26, 47)
# (27, 42)
# (27, 47)
# (29, 8)
# (29, 41)
# (29, 8)
# (30, 8)
# (29, 41)
# (30, 41)
# (30, 49)
# (30, 8)
# (30, 41)
# (30, 49)
# (31, 48)
# (30, 49)
# (31, 50)
# (31, 8)
# (31, 47)
# (31, 46)
# (31, 47)
# (31, 47)
# (31, 50)
# (33, 46)
# (33, 47)
# (32, 50)
# (32, 50)
# (34, 50)
# (35, 40)
# (34, 50)
# (35, 40)
# (36, 46)
# (36, 50)
# (36, 50)
# (37, 47)
# (37, 47)
# (38, 41)
# (38, 43)
# (38, 43)
# (41, 8)
# (42, 8)
# (43, 8)
# (44, 8)
# (45, 8)
# (51, 8)
# (86, 49)
# (86, 49)
# (87, 48)
# (86, 49)
# (87, 44)
# (88, 44)
# (87, 49)
# (87, 50)
# (88, 44)
# (89, 5)
# (90, 40)
# (89, 48)
# (89, 48)
# (90, 5)
# (90, 40)
# (91, 5)
# (92, 38)
# (92, 5)
# (92, 38)
# (93, 5)
# (93, 39)
# (93, 39)
# (98, 5)
# (98, 5)
# (100, 28)
# (100, 28)
# (100, 28)
# (103, 20)
# (104, 27)
# (104, 27)
# (105, 22)
# (105, 22)
# (106, 24)
# (106, 24)
# (106, 24)
# (108, 58)
# (108, 58)
# (110, 60)
# (111, 53)
# (110, 60)
# (111, 53)
# (116, 55)
# (116, 55)
# (116, 60)
# (116, 60)
# (117, 55)
# (118, 56)
# (118, 56)
# (120, 4)
# (119, 58)
# (119, 58)
# (119, 58)
# (120, 4)
# (121, 5)

# %%
mask = xr.where(experiment.notnull(), 1, 0)  # 1 = valid, 0 = invalid
mask.to_zarr(f"valid_mask_{plevel}hPa.zarr")

# %%
plot.plot_single_plot(ds_test_truth['surface_temperature'].isel(time=6*60).T, f'temp at surface', 'temperature', (0,350), 'viridis', "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/", 'test_surf')
plot.plot_single_plot(ds_test_forecast['surface_temperature'].isel(time=6*60).T, f'temp forecast at surface', 'temperature', (0,350), 'viridis', "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/eval_ukesm/", 'test_forecast_surf')

# %%
all_performance_1819 = []
all_performance_2049 = []
all_shift_map_2049 = []
all_relative_performance_error = []
all_absolute_performance_error = []
all_relative_performance_percentage = []
all_mean_truth_difference=[]
weighted_wasserstein = []
weighted_rmse_list = []
all_truth_201819 = []
all_truth_2049 = []
all_forecast_201819 = []
all_forecast_2049 = []

mixed = False
historical_year='2019'
future_year='2049'
error_after_hours = 120 # Must be dividable by 6


assert (error_after_hours % 6) == 0 and error_after_hours > 0
error_after_x_steps = int(error_after_hours / 6) - 1

# First prediction is always at 00 or 12 -> if error_after_x_steps is odd, we only look at 00 and 12 time values 
# If not, we only look at 06 and 18 time values
if error_after_x_steps % 2 == 0:
    filter_hours = [6,18]
else: filter_hours = [0,12]

if mixed:
    base_save_folder = "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/trained_models/nextgems_1990_2020_6h-128x64_try2_z64/plots/"
else:
    # base_save_folder = "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/trained_models/nextgems_1990_2020_6h-128x64_equiangular_with_poles_conservative_z64/plots/"
    base_save_folder = "/home/hk-project-pai00005/xo8179/neural_lam_fork/neural-lam/trained_models/nextgems_1990_2020_6h-128x64_equiangular_with_poles_conservative_z128/plots/"

for display_name, unit, variable, plevel in plot.KEY_VARIABLES:
    
    
    if mixed:
        truth_hist = nextgems_mixed_truth_1819.sel(time=historical_year).isel(time=slice(0,-1))[variable]
        truth_future = nextgems_mixed_truth_49.sel(time=future_year)[variable]
        forecast_hist = nextgems_1990_2020_mixed_z64.sel(time=historical_year)[variable].sel(time=nextgems_1990_2020_mixed_z64.time.dt.hour.isin([0, 12])).isel(time=slice(10,-10))
        forecast_future = nextgems_2049_mixed_z64.sel(time=future_year)[variable].sel(time=nextgems_2049_mixed_z64.time.dt.hour.isin([0, 12])).isel(time=slice(10,-10))
    else:
        truth_hist = nextgems_equiangular_wp_cons_truth_1819.sel(time=historical_year)[variable]
        truth_hist = truth_hist.isel(time=slice(2+error_after_x_steps,-(38-error_after_x_steps)))
        truth_hist = truth_hist.sel(time=truth_hist.time.dt.hour.isin(filter_hours))
        truth_future = nextgems_equiangular_wp_cons_truth_49.sel(time=future_year)[variable]
        truth_future = truth_future.isel(time=slice(2+error_after_x_steps,-(38-error_after_x_steps)))
        truth_future = truth_future.sel(time=truth_future.time.dt.hour.isin(filter_hours))
        forecast_hist = nextgems_1990_2020_equiangular_wp_cons_z128.sel(time=historical_year)[variable].isel(prediction_timedelta=error_after_x_steps)
        forecast_future = nextgems_2049_equiangular_wp_cons_z128.sel(time=future_year)[variable].isel(prediction_timedelta=error_after_x_steps)
        print(forecast_hist['time'])
        print(truth_hist['time'])
        forecast_hist['time'] = truth_hist['time']
        forecast_future['time'] = truth_future['time']
        
        
    if plevel:
        truth_hist = truth_hist.sel(level=plevel)
        truth_future = truth_future.sel(level=plevel)
        forecast_hist = forecast_hist.sel(level=plevel)
        forecast_future = forecast_future.sel(level=plevel)
        
    

    all_truth_201819.append(truth_hist)
    all_truth_2049.append(truth_future)
    all_forecast_201819.append(forecast_hist)
    all_forecast_2049.append(forecast_future)
    performance_1819 = rmse(truth_hist, forecast_hist)
    performance_2049 = rmse(truth_future, forecast_future)
    all_relative_performance_percentage.append((performance_2049 - performance_1819) / performance_1819 * 100)
    all_performance_1819.append(performance_1819)
    all_performance_2049.append(performance_2049)
    all_shift_map_2049.append(shift_per_gridcell(truth_hist, truth_future))
    weighted_wasserstein.append(shift_global(truth_hist, truth_future))
    weighted_rmse_1819 = weighted_rmse(truth_hist, forecast_hist)
    weighted_rmse_49 = weighted_rmse(truth_future, forecast_future)
    weighted_rmse_list.append((weighted_rmse_49 - weighted_rmse_1819) / weighted_rmse_1819 * 100)
    all_relative_performance_error.append(performance_2049 / performance_1819)
    all_absolute_performance_error.append(performance_2049 - performance_1819)
    all_mean_truth_difference.append(truth_future.mean('time') - truth_hist.mean('time'))
# Out:
# <xarray.DataArray 'time' (time: 710)> Size: 6kB
# array(['2019-01-01T06:00:00.000000000', '2019-01-01T18:00:00.000000000',
#        '2019-01-02T06:00:00.000000000', ..., '2019-12-20T18:00:00.000000000',
#        '2019-12-21T06:00:00.000000000', '2019-12-21T18:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#     prediction_timedelta  timedelta64[ns] 8B 00:00:00.000000120
#   * time                  (time) datetime64[ns] 6kB 2019-01-01T06:00:00 ... 2...
# <xarray.DataArray 'time' (time: 710)> Size: 6kB
# array(['2019-01-06T12:00:00.000000000', '2019-01-07T00:00:00.000000000',
#        '2019-01-07T12:00:00.000000000', ..., '2019-12-26T00:00:00.000000000',
#        '2019-12-26T12:00:00.000000000', '2019-12-27T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 6kB 2019-01-06T12:00:00 ... 2019-12-27
# <xarray.DataArray 'time' (time: 710)> Size: 6kB
# array(['2019-01-01T06:00:00.000000000', '2019-01-01T18:00:00.000000000',
#        '2019-01-02T06:00:00.000000000', ..., '2019-12-20T18:00:00.000000000',
#        '2019-12-21T06:00:00.000000000', '2019-12-21T18:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#     prediction_timedelta  timedelta64[ns] 8B 00:00:00.000000120
#   * time                  (time) datetime64[ns] 6kB 2019-01-01T06:00:00 ... 2...
# <xarray.DataArray 'time' (time: 710)> Size: 6kB
# array(['2019-01-06T12:00:00.000000000', '2019-01-07T00:00:00.000000000',
#        '2019-01-07T12:00:00.000000000', ..., '2019-12-26T00:00:00.000000000',
#        '2019-12-26T12:00:00.000000000', '2019-12-27T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 6kB 2019-01-06T12:00:00 ... 2019-12-27
# <xarray.DataArray 'time' (time: 710)> Size: 6kB
# array(['2019-01-01T06:00:00.000000000', '2019-01-01T18:00:00.000000000',
#        '2019-01-02T06:00:00.000000000', ..., '2019-12-20T18:00:00.000000000',
#        '2019-12-21T06:00:00.000000000', '2019-12-21T18:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#     prediction_timedelta  timedelta64[ns] 8B 00:00:00.000000120
#   * time                  (time) datetime64[ns] 6kB 2019-01-01T06:00:00 ... 2...
# <xarray.DataArray 'time' (time: 710)> Size: 6kB
# array(['2019-01-06T12:00:00.000000000', '2019-01-07T00:00:00.000000000',
#        '2019-01-07T12:00:00.000000000', ..., '2019-12-26T00:00:00.000000000',
#        '2019-12-26T12:00:00.000000000', '2019-12-27T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 6kB 2019-01-06T12:00:00 ... 2019-12-27
# <xarray.DataArray 'time' (time: 710)> Size: 6kB
# array(['2019-01-01T06:00:00.000000000', '2019-01-01T18:00:00.000000000',
#        '2019-01-02T06:00:00.000000000', ..., '2019-12-20T18:00:00.000000000',
#        '2019-12-21T06:00:00.000000000', '2019-12-21T18:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#     prediction_timedelta  timedelta64[ns] 8B 00:00:00.000000120
#   * time                  (time) datetime64[ns] 6kB 2019-01-01T06:00:00 ... 2...
# <xarray.DataArray 'time' (time: 710)> Size: 6kB
# array(['2019-01-06T12:00:00.000000000', '2019-01-07T00:00:00.000000000',
#        '2019-01-07T12:00:00.000000000', ..., '2019-12-26T00:00:00.000000000',
#        '2019-12-26T12:00:00.000000000', '2019-12-27T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 6kB 2019-01-06T12:00:00 ... 2019-12-27
# <xarray.DataArray 'time' (time: 710)> Size: 6kB
# array(['2019-01-01T06:00:00.000000000', '2019-01-01T18:00:00.000000000',
#        '2019-01-02T06:00:00.000000000', ..., '2019-12-20T18:00:00.000000000',
#        '2019-12-21T06:00:00.000000000', '2019-12-21T18:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#     prediction_timedelta  timedelta64[ns] 8B 00:00:00.000000120
#   * time                  (time) datetime64[ns] 6kB 2019-01-01T06:00:00 ... 2...
# <xarray.DataArray 'time' (time: 710)> Size: 6kB
# array(['2019-01-06T12:00:00.000000000', '2019-01-07T00:00:00.000000000',
#        '2019-01-07T12:00:00.000000000', ..., '2019-12-26T00:00:00.000000000',
#        '2019-12-26T12:00:00.000000000', '2019-12-27T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 6kB 2019-01-06T12:00:00 ... 2019-12-27
# <xarray.DataArray 'time' (time: 710)> Size: 6kB
# array(['2019-01-01T06:00:00.000000000', '2019-01-01T18:00:00.000000000',
#        '2019-01-02T06:00:00.000000000', ..., '2019-12-20T18:00:00.000000000',
#        '2019-12-21T06:00:00.000000000', '2019-12-21T18:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#     prediction_timedelta  timedelta64[ns] 8B 00:00:00.000000120
#   * time                  (time) datetime64[ns] 6kB 2019-01-01T06:00:00 ... 2...
# <xarray.DataArray 'time' (time: 710)> Size: 6kB
# array(['2019-01-06T12:00:00.000000000', '2019-01-07T00:00:00.000000000',
#        '2019-01-07T12:00:00.000000000', ..., '2019-12-26T00:00:00.000000000',
#        '2019-12-26T12:00:00.000000000', '2019-12-27T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 6kB 2019-01-06T12:00:00 ... 2019-12-27
# <xarray.DataArray 'time' (time: 710)> Size: 6kB
# array(['2019-01-01T06:00:00.000000000', '2019-01-01T18:00:00.000000000',
#        '2019-01-02T06:00:00.000000000', ..., '2019-12-20T18:00:00.000000000',
#        '2019-12-21T06:00:00.000000000', '2019-12-21T18:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#     prediction_timedelta  timedelta64[ns] 8B 00:00:00.000000120
#   * time                  (time) datetime64[ns] 6kB 2019-01-01T06:00:00 ... 2...
# <xarray.DataArray 'time' (time: 710)> Size: 6kB
# array(['2019-01-06T12:00:00.000000000', '2019-01-07T00:00:00.000000000',
#        '2019-01-07T12:00:00.000000000', ..., '2019-12-26T00:00:00.000000000',
#        '2019-12-26T12:00:00.000000000', '2019-12-27T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 6kB 2019-01-06T12:00:00 ... 2019-12-27

# %%
# Zonally weighted
for i, (display_name, unit, variable, plevel) in enumerate(plot.KEY_VARIABLES):
    plot_distributions(all_truth_201819[i], all_truth_2049[i], variable_name='Ground truth: '+ display_name, save_to=base_save_folder + f'truth_distribution_shift/{display_name.replace(" ", "_")}_zonally_weighted.png')

# %%
for i, (display_name, unit, variable, plevel) in enumerate(plot.KEY_VARIABLES):
    plevel_display = f' at {plevel}hPa' if plevel else ' at surface'
    plot.plot_zonal_plot(
        all_mean_truth_difference[i],
        title=f"Absolute difference in {display_name} (2049 vs 2019)",
        y_label=f"Absolute difference (2049 / 2019) in {unit}",
        #vbounds=(-max_val,max_val),
        base_save_folder=base_save_folder+"zonal_average_shift/",
        save_name=f"zonal_truth_difference_{variable}{plevel_display.replace(' ', '_')}",
        label_below="Value decrease (in 2049)",
        label_above="Value increase (in 2049)",
        centered_around=0,
        color_above='green',
        color_below='red'
    )

# %%
for i, (display_name, unit, variable, plevel) in enumerate(plot.KEY_VARIABLES):
    plevel_display = f' at {plevel}hPa' if plevel else ' at surface'
    plot.plot_zonal_plot(
        all_relative_performance_percentage[i],
        title=f"Zonal mean of relative performance error after {error_after_x_steps} steps (2049 vs 2019)\n{display_name}",
        y_label="Relative RMSE (2049 - 2019) / 2019 in %",
        centered_around=0,
        base_save_folder=base_save_folder+"zonal_relative_performance/",
        save_name=f"zonal_relative_performance_percentage_{variable}{plevel_display.replace(' ', '_')}_after{error_after_x_steps}steps"
    )

# %%
plt.figure(figsize=(7,6))
plt.scatter(weighted_wasserstein, weighted_rmse_list)
for i, (display_name, unit, variable, plevel) in enumerate(plot.KEY_VARIABLES):
    plevel_display = f' at {plevel}hPa' if plevel else ' at surface'
    # Annotate each variable
    plt.text(weighted_wasserstein[i]*1.01, weighted_rmse_list[i]*1.01, display_name)

plt.axhline(0, color="gray", linestyle="--", linewidth=1)
plt.xlabel("Wasserstein distance (normalized, area-weighted)")
plt.xlim(0, max(weighted_wasserstein) * 1.7)
plt.ylabel("Performance degradation (%)")
plt.title("Model robustness: 2049 vs 2019 (weighted)")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(base_save_folder+"relative_performance_degradation_per_normalized_wasserstein_distance_.png", dpi=300)
plt.close()

# %% [markdown]
# ### Local RMSE per Wasserstein distance
#
# Computing the Wasserstein distance between the distribution per gridpoint over 2049 and the global distribution in 2049.
# Plot the local RMSE per grid point after x steps onto the local Wasserstein distance.

# %%
index = 1

gt = all_truth_2049[index].astype(np.float32).load()  # (time, lon, lat)
sim_sel = all_forecast_2049[index].astype(np.float32).load()   # (time, lon, lat)
relative_rmse_difference = (all_performance_2049[index]-all_performance_1819[index])/all_performance_1819[index]
true_data_mean = all_truth_2049[index].mean(dim='time')
true_data_mean_19 = all_truth_201819[index].mean(dim='time') 

display_name, unit, variable, plevel = plot.KEY_VARIABLES[index]
plevel_display = f' at {plevel}hPa' if plevel else ' at surface'

# %%
from joblib import Parallel, delayed
import numpy as np
import xarray as xr
from tqdm import tqdm

gt_vals = gt.values
sim_vals = sim_sel.values

# --- Latitude weights ---
lats = gt["latitude"].values
w_lat = np.cos(np.deg2rad(lats))
w_lat = w_lat / w_lat.mean()

# Broadcast weights to (time, lon, lat)
W = xr.DataArray(
    np.broadcast_to(w_lat[np.newaxis, np.newaxis, :],
                    gt.shape),
    coords=gt.coords, dims=gt.dims
)

# Precompute flattened global distribution
vals_global = gt_vals.flatten()
wg_global   = W.values.flatten()

mask_global = np.isfinite(vals_global)
vals_global = vals_global[mask_global]
wg_global   = wg_global[mask_global]

# Convert coords to plain floats (important for joblib!)
lons = gt.longitude.values.astype(float)
lats = gt.latitude.values.astype(float)
points = [(lon, lat) for lon in lons for lat in lats]
lon_index = {lon: i for i, lon in enumerate(gt.longitude.values)}
lat_index = {lat: j for j, lat in enumerate(gt.latitude.values)}

some_local_gt = gt_vals[:, 0, 0]
w_local = np.ones_like(some_local_gt)

def process_point(lon, lat):
    # Extract raw NumPy arrays (avoids slow .sel each call)
    i, j = lon_index[lon], lat_index[lat]
    local_gt = gt_vals[:, i, j]    
    local_sim = sim_vals[:, i, j]  

    ws = float(weighted_wasserstein_1d(local_gt, vals_global, w_local, wg_global))
    rmse = float(np.sqrt(np.mean((local_sim - local_gt) ** 2)))
    return ws, rmse

# Parallel loop
results = Parallel(n_jobs=-1, backend="loky")(
    delayed(process_point)(lon, lat) for lon, lat in tqdm(points)
)

# Convert results directly to arrays for plotting
results = np.array(results)   # shape (npoints, 2)
ws_distances = results[:, 0]
rmses = results[:, 1]
# Out:
# 100%|██████████| 8192/8192 [07:55<00:00, 17.22it/s]

# %%
plt.figure(figsize=(7,6))
plt.scatter(ws_distances, relative_rmse_difference, alpha=0.3, s=10)
plt.xlabel(f"Wasserstein distance between local and global distribution for {display_name}")
plt.ylabel("Relative RMSE (2049-2019)/2019 in %")
plt.title(f"Local relative RMSE per local distribution shift - {display_name}")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(base_save_folder+variable+f"/rel_rmse_per_local_to_global_wasserstein_point_{variable}{plevel_display.replace(' ', '_')}.png", dpi=300)

# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from importlib import reload
reload(plot)
import plot_utils as plot 

# Get lon/lat coordinates
lons = gt.longitude.values
lats = gt.latitude.values

# Reshape 1D arrays into 2D grids
n_lon = len(lons)
n_lat = len(lats)

ws_grid = np.reshape(ws_distances, (n_lon, n_lat))   
rmse_grid = np.reshape(rmses, (n_lon, n_lat))       

ws_ds = xr.Dataset(
            {variable: (('longitude','latitude'), ws_grid)},
            coords={
        "latitude": lats,
        "longitude": lons,
    })

# Optional: flip latitude if needed for plotting
if lats[0] > lats[-1]:
    ws_grid = ws_grid[::-1, :]
    rmse_grid = rmse_grid[::-1, :]
    lats = lats[::-1]

plot.plot_double_plot(data_left=ws_ds[variable].T,
                 title_left=f"Distribution shift (Wasserstein, 2049 local to global)\n{display_name}",
                 cbar_label_left="Distribution shift",
                 vbounds_left=None,
                 cmap_left="Reds",
                 data_right=true_data_mean.T,
                 title_right=f"Yearly average (2049)\n{display_name}",
                 cbar_label_right=unit,
                 vbounds_right=None,
                 cmap_right="coolwarm",
                 base_save_folder=base_save_folder,
                 save_name=variable+f"/local_to_global_wasserstein_and_yearly_average_{variable}{plevel_display.replace(' ', '_')}")

                
# plot_map(all_truth_2049[0].mean(dim='time'), lons, lats, title="Ground truth 49")
plot.plot_single_plot(data_left=relative_rmse_difference.T,
                 title_left=f"Relative RMSE difference (2049-2019)/2019 after {error_after_x_steps} steps",
                 cbar_label_left="Relative RMSE difference in %",
                 vbounds_left=None,
                 cmap_left="coolwarm",
                 base_save_folder=base_save_folder,
                 save_name=variable+f"/relative_rmse_2049_to_2019_after_{error_after_x_steps}steps_{variable}{plevel_display.replace(' ', '_')}")
plot.plot_single_plot(data_left=(true_data_mean - true_data_mean_19).T,
                 title_left=f"Mean value difference (2049-2019)",
                 cbar_label_left=f"Mean difference in {unit}",
                 vbounds_left=None,
                 cmap_left="coolwarm",
                 base_save_folder=base_save_folder,
                 save_name=variable+f"/mean_value_difference_2049_to_2019_{variable}{plevel_display.replace(' ', '_')}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 17
#      14 n_lon = len(lons)
#      15 n_lat = len(lats)
# ---> 17 ws_grid = np.reshape(ws_distances, (n_lon, n_lat))
#      18 rmse_grid = np.reshape(rmses, (n_lon, n_lat))
#      20 ws_ds = xr.Dataset(
#      21             {variable: (('longitude','latitude'), ws_grid)},
#      22             coords={
#      23         "latitude": lats,
#      24         "longitude": lons,
#      25     })
#
# NameError: name 'ws_distances' is not defined

# %%
lats = truth_hist['latitude'].values
w_lat = np.cos(np.deg2rad(lats))
print(w_lat)
# Out:
# [6.12323400e-17 4.98458857e-02 9.95678466e-02 1.49042266e-01
#  1.98146143e-01 2.46757398e-01 2.94755174e-01 3.42020143e-01
#  3.88434796e-01 4.33883739e-01 4.78253979e-01 5.21435203e-01
#  5.63320058e-01 6.03804410e-01 6.42787610e-01 6.80172738e-01
#  7.15866849e-01 7.49781203e-01 7.81831482e-01 8.11938006e-01
#  8.40025923e-01 8.66025404e-01 8.89871809e-01 9.11505852e-01
#  9.30873749e-01 9.47927346e-01 9.62624247e-01 9.74927912e-01
#  9.84807753e-01 9.92239207e-01 9.97203797e-01 9.99689182e-01
#  9.99689182e-01 9.97203797e-01 9.92239207e-01 9.84807753e-01
#  9.74927912e-01 9.62624247e-01 9.47927346e-01 9.30873749e-01
#  9.11505852e-01 8.89871809e-01 8.66025404e-01 8.40025923e-01
#  8.11938006e-01 7.81831482e-01 7.49781203e-01 7.15866849e-01
#  6.80172738e-01 6.42787610e-01 6.03804410e-01 5.63320058e-01
#  5.21435203e-01 4.78253979e-01 4.33883739e-01 3.88434796e-01
#  3.42020143e-01 2.94755174e-01 2.46757398e-01 1.98146143e-01
#  1.49042266e-01 9.95678466e-02 4.98458857e-02 6.12323400e-17]

# %%
print(all_relative_performance_percentage)
# Out:
# [<xarray.DataArray 'geopotential' (longitude: 128, latitude: 64)> Size: 66kB
# dask.array<mul, shape=(128, 64), dtype=float64, chunksize=(128, 64), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude              (latitude) float64 512B -90.0 -87.14 ... 87.14 90.0
#     level                 int64 8B 500
#   * longitude             (longitude) float64 1kB 0.0 2.812 ... 354.4 357.2
#     prediction_timedelta  timedelta64[ns] 8B 00:00:00.000000120, <xarray.DataArray 'temperature' (longitude: 128, latitude: 64)> Size: 66kB
# dask.array<mul, shape=(128, 64), dtype=float64, chunksize=(128, 64), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude              (latitude) float64 512B -90.0 -87.14 ... 87.14 90.0
#     level                 int64 8B 850
#   * longitude             (longitude) float64 1kB 0.0 2.812 ... 354.4 357.2
#     prediction_timedelta  timedelta64[ns] 8B 00:00:00.000000120, <xarray.DataArray 'specific_humidity' (longitude: 128, latitude: 64)> Size: 66kB
# dask.array<mul, shape=(128, 64), dtype=float64, chunksize=(128, 64), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude              (latitude) float64 512B -90.0 -87.14 ... 87.14 90.0
#     level                 int64 8B 700
#   * longitude             (longitude) float64 1kB 0.0 2.812 ... 354.4 357.2
#     prediction_timedelta  timedelta64[ns] 8B 00:00:00.000000120, <xarray.DataArray '2m_temperature' (longitude: 128, latitude: 64)> Size: 66kB
# dask.array<mul, shape=(128, 64), dtype=float64, chunksize=(128, 64), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude              (latitude) float64 512B -90.0 -87.14 ... 87.14 90.0
#   * longitude             (longitude) float64 1kB 0.0 2.812 ... 354.4 357.2
#     prediction_timedelta  timedelta64[ns] 8B 00:00:00.000000120, <xarray.DataArray 'u_component_of_wind' (longitude: 128, latitude: 64)> Size: 66kB
# dask.array<mul, shape=(128, 64), dtype=float64, chunksize=(128, 64), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude              (latitude) float64 512B -90.0 -87.14 ... 87.14 90.0
#     level                 int64 8B 850
#   * longitude             (longitude) float64 1kB 0.0 2.812 ... 354.4 357.2
#     prediction_timedelta  timedelta64[ns] 8B 00:00:00.000000120, <xarray.DataArray 'v_component_of_wind' (longitude: 128, latitude: 64)> Size: 66kB
# dask.array<mul, shape=(128, 64), dtype=float64, chunksize=(128, 64), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude              (latitude) float64 512B -90.0 -87.14 ... 87.14 90.0
#     level                 int64 8B 850
#   * longitude             (longitude) float64 1kB 0.0 2.812 ... 354.4 357.2
#     prediction_timedelta  timedelta64[ns] 8B 00:00:00.000000120, <xarray.DataArray 'total_precipitation_6hr' (longitude: 128, latitude: 64)> Size: 66kB
# dask.array<mul, shape=(128, 64), dtype=float64, chunksize=(128, 64), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude              (latitude) float64 512B -90.0 -87.14 ... 87.14 90.0
#   * longitude             (longitude) float64 1kB 0.0 2.812 ... 354.4 357.2
#     prediction_timedelta  timedelta64[ns] 8B 00:00:00.000000120]

# %%
calculated_rmse = [(x.mean(dim="longitude") * w_lat).sum() / w_lat.sum() for x in all_relative_performance_percentage]

# %%
plt.figure(figsize=(7,6))
plt.scatter(weighted_wasserstein, calculated_rmse)
for i, (display_name, unit, variable, plevel) in enumerate(plot.KEY_VARIABLES):
    plevel_display = f' at {plevel}hPa' if plevel else ' at surface'
    # Annotate each variable
    plt.text(weighted_wasserstein[i]*1.01, calculated_rmse[i]*1.01, display_name)

plt.axhline(0, color="gray", linestyle="--", linewidth=1)
plt.xlabel("Wasserstein distance (normalized, area-weighted)")
plt.xlim(max(weighted_wasserstein)*1.7)
plt.ylabel("Performance degradation (%)")
plt.title("Model robustness: 2049 vs 2019 (weighted)")
plt.grid(True, alpha=0.3)
plt.savefig(base_save_folder+"relative_performance_degradation_per_normalized_wasserstein_distance.png", dpi=300)

# %%
plot.plot_double_plot(data_left=shift_map_2049.T,
                 title_left=f"Distribution shift (Wasserstein, 2049 vs 2019)\n{variable}{f' at {plevel}hPa' if plevel else ''}",
                 cbar_label_left="Distribution shift",
                 vbounds_left=None,
                 cmap_left="Reds",
                 data_right=relative_performance_error.T,
                 title_right=f"Relative performance degradation (RMSE 2049 / 2019)\n{variable}{f' at {plevel}hPa' if plevel else ''}",
                 cbar_label_right="Relative performance degradation",
                 vbounds_right=(0.3, 1.7),
                 cmap_right="coolwarm",
                 base_save_folder=base_save_folder,
                 save_name=f'shift_relative_performance_{info_to_save}')

# %%
plot.plot_double_plot(data_left=relative_performance_error.T,
                 title_left=f"Relative performance degradation (RMSE 2049 / 2019)\n{variable}{f' at {plevel}hPa' if plevel else ''}",
                 cbar_label_left="Relative performance degradation",
                 vbounds_left=(0.3, 1.7),
                 cmap_left="coolwarm",
                 data_right=absolute_performance_error.T,
                 title_right=f"Absolute performance degradation (RMSE 2049 - 2019)\n{variable}{f' at {plevel}hPa' if plevel else ''}",
                 cbar_label_right="Absolute performance degradation",
                 vbounds_right=None,
                 cmap_right="coolwarm",
                 base_save_folder=base_save_folder,
                 save_name=f"absolute_relative_performance_{info_to_save}")

# %%
proj = ccrs.PlateCarree()
fig, axes = plt.subplots(1, 1, figsize=(7,6), subplot_kw={"projection": proj})
(relative_performance_error / shift_map_2049).T.plot(ax=axes, cmap="Reds", transform=proj, vmax=6, cbar_kwargs={"shrink": 0.5, "aspect": 25, "label": "Normalized difference"})
axes.add_feature(cfeature.COASTLINE, linewidth=0.8)
axes.add_feature(cfeature.BORDERS, linewidth=0.5)
axes.set_title(f"Relative performance degradation / Distribution shift (Wasserstein)\n2049 vs 2019, {variable}{f' at {plevel}hPa' if plevel else ''}")

plt.tight_layout()
plt.savefig(base_save_folder+f"normalized_performance_degradation_{info_to_save}.png", dpi=300, bbox_inches='tight')
