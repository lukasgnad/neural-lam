# %%
import xarray as xr
from matplotlib import pyplot as plt
import xarray as xr

# %%
fields_xds = xr.open_zarr('/hkfs/work/workspace/scratch/xo8179-NG_new/global_nextgems_minimal_1990_2020_6h-128x64_equiangular_with_poles_conservative/fields.zarr')

# %%
from neural_lam.configs import get_constants
C = get_constants('nextgems_minimal')

# %%
print(fields_xds)
# Out:
# <xarray.Dataset> Size: 121GB
# Dimensions:                  (time: 43828, longitude: 128, latitude: 64,
#                               level: 13)
# Coordinates:
#   * latitude                 (latitude) float64 512B -90.0 -87.14 ... 87.14 90.0
#   * level                    (level) int64 104B 50 100 150 200 ... 850 925 1000
#   * longitude                (longitude) float64 1kB 0.0 2.812 ... 354.4 357.2
#   * time                     (time) datetime64[ns] 351kB 1990-01-01 ... 2019-...
# Data variables: (12/14)
#     10m_u_component_of_wind  (time, longitude, latitude) float32 1GB dask.array<chunksize=(50, 128, 64), meta=np.ndarray>
#     10m_v_component_of_wind  (time, longitude, latitude) float32 1GB dask.array<chunksize=(50, 128, 64), meta=np.ndarray>
#     2m_temperature           (time, longitude, latitude) float32 1GB dask.array<chunksize=(50, 128, 64), meta=np.ndarray>
# ...

# %%
vars_to_keep = set(C.ATMOSPHERIC_PARAMS) | set(C.SURFACE_PARAMS) | set(C.PREPROCESSING_PARAMS)
vars_to_keep = [v for v in vars_to_keep if v in fields_xds.data_vars]
fields_xds = fields_xds[vars_to_keep]

fields_xds = fields_xds.sel(level=C.PRESSURE_LEVELS)

# %%
ds = ds.sel(level=C.PRESSURE_LEVELS)

# %%
ds
# Out:
# <xarray.Dataset> Size: 52GB
# Dimensions:                  (time: 43828, level: 6, longitude: 128,
#                               latitude: 64)
# Coordinates:
#   * latitude                 (latitude) float64 512B -90.0 -87.14 ... 87.14 90.0
#   * level                    (level) int64 48B 925 850 700 500 300 200
#   * longitude                (longitude) float64 1kB 0.0 2.812 ... 354.4 357.2
#   * time                     (time) datetime64[ns] 351kB 1990-01-01 ... 2019-...
# Data variables: (12/13)
#     u_component_of_wind      (time, level, longitude, latitude) float32 9GB dask.array<chunksize=(50, 6, 128, 64), meta=np.ndarray>
#     v_component_of_wind      (time, level, longitude, latitude) float32 9GB dask.array<chunksize=(50, 6, 128, 64), meta=np.ndarray>
#     geopotential_500         (time, longitude, latitude) float32 1GB dask.array<chunksize=(50, 128, 64), meta=np.ndarray>
# ...
